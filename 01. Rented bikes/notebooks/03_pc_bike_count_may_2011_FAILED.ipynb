# %%
import statsmodels.tools.eval_measures as sm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/dc_bikes_with_features.csv", parse_dates=['datetime'], dayfirst=True, index_col=0)
df
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count  year  \
# ...

# %%
df.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'count', 'year',
#        'month', 'day', 'hour', 'minute', 'part_of_day'],
#       dtype='object')

# %%
df.index = df.index.to_series().dt.strftime('%d-%m-%y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.index = df.index.to_series().dt.strftime('%d-%m-%y')
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~\miniconda3\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df_may_2011 = df[(df['year'] == 2011) & (df['month'] == 5)]

# %%
count_column_11 = df_may_2011['count']
count_column_11
# Out:
# datetime
# 2011-05-01 00:00:00      6
# 2011-05-01 01:00:00      6
# 2011-05-01 02:00:00      2
# 2011-05-01 04:00:00      2
# 2011-05-01 05:00:00      3
#                       ...
# 2011-05-12 19:00:00    308
# 2011-05-12 20:00:00    205
# 2011-05-12 21:00:00    176
# 2011-05-12 22:00:00    106
# 2011-05-12 23:00:00     62
# Name: count, Length: 743, dtype: int64

# %%
df_may_2012 = df[(df['year'] == 2012) & (df['month'] == 5)]

# %%
count_column_12 = df_may_2012['count']
count_column_12
# Out:
# datetime
# 2012-05-01 00:00:00     14
# 2012-05-01 01:00:00      5
# 2012-05-01 02:00:00      4
# 2012-05-01 03:00:00      4
# 2012-05-01 04:00:00      5
#                       ...
# 2012-05-12 19:00:00    414
# 2012-05-12 20:00:00    293
# 2012-05-12 21:00:00    198
# 2012-05-12 22:00:00    105
# 2012-05-12 23:00:00     74
# Name: count, Length: 744, dtype: int64
