# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
happy = pd.read_csv('./Happiness_level_by_year.csv')
happy
# Out:
#       Unnamed: 0       country      continent  year  happiness
# 0              0       Algeria         Africa  2005        NaN
# 1             73        Turkey           Asia  2005       47.2
# 2              2         Benin         Africa  2005        NaN
# 3              3      Botswana         Africa  2005        NaN
# 4              4       Burundi         Africa  2005        NaN
# ...          ...           ...            ...   ...        ...
# 2215        2215      Paraguay  South America  2019       56.9
# 2216        2216          Peru  South America  2019       58.0
# 2217        2146  Turkmenistan           Asia  2019       51.2
# 2218        2182      Portugal         Europe  2019       59.1
# 2219        2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 5 columns]

# %%
countries_to_filter = ['Togo', 'South Africa', 'Turkey', 'Saudi Arabia', 'Romania', 'Denmark', 'Haiti', 'United States', 'Australia', 'New Zealand', 'Ecuador', 'Brazil']

# %%
filtered_df = happy[(happy['country'].isin(countries_to_filter))] 
filtered_df
# Out:
#       Unnamed: 0        country              continent  year  happiness
# 1             73         Turkey                   Asia  2005       47.2
# 33            34   South Africa                 Africa  2005        NaN
# 53            38           Togo                 Africa  2005        NaN
# 66            67   Saudi Arabia                   Asia  2005       70.8
# 89            90        Denmark                 Europe  2005       80.2
# ...          ...            ...                    ...   ...        ...
# 2205        2205  United States          North America  2019       69.4
# 2206        2206      Australia  Australia and Oceania  2019       72.2
# 2207        2207    New Zealand  Australia and Oceania  2019       73.0
# 2210        2210         Brazil          South America  2019       63.8
# 2213        2213        Ecuador          South America  2019       59.3
#
# [180 rows x 5 columns]

# %%
democ = pd.read_csv('./democracy.csv')
democ
# Out:
#                   country  2006  2007  2008  2009  2010  2011  2012  2013  \
# 0             Afghanistan  30.6  30.4  30.2  27.5  24.8  24.8  24.8  24.8
# 1                  Angola  24.1  28.8  33.5  33.4  33.2  33.2  33.5  33.5
# 2                 Albania  59.1  59.1  59.1  58.9  58.6  58.1  56.7  56.7
# 3    United Arab Emirates  24.2  25.1  26.0  25.6  25.2  25.8  25.8  25.2
# 4               Argentina  66.3  66.3  66.3  67.3  68.4  68.4  68.4  68.4
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 162               Vietnam  27.5  26.4  25.3  27.4  29.4  29.6  28.9  32.9
# 163                 Yemen  29.8  29.6  29.5  27.9  26.4  25.7  31.2  27.9
# 164          South Africa  79.1  79.1  79.1  78.5  77.9  77.9  77.9  79.0
# 165                Zambia  52.5  52.5  52.5  54.6  56.8  61.9  62.6  62.6
# 166              Zimbabwe  26.2  25.8  25.3  25.9  26.4  26.8  26.7  26.7
#
#      2014  2015  2016  2017  2018  2019  2020
# ...

# %%
happy
# Out:
#       Unnamed: 0       country      continent  year  happiness
# 0              0       Algeria         Africa  2005        NaN
# 1             73        Turkey           Asia  2005       47.2
# 2              2         Benin         Africa  2005        NaN
# 3              3      Botswana         Africa  2005        NaN
# 4              4       Burundi         Africa  2005        NaN
# ...          ...           ...            ...   ...        ...
# 2215        2215      Paraguay  South America  2019       56.9
# 2216        2216          Peru  South America  2019       58.0
# 2217        2146  Turkmenistan           Asia  2019       51.2
# 2218        2182      Portugal         Europe  2019       59.1
# 2219        2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 5 columns]

# %%
democ_long = pd.melt(democ, id_vars='country', var_name='year', value_name='democracy_score')

# %%
democ_long
# Out:
#                    country  year  democracy_score
# 0              Afghanistan  2006             30.6
# 1                   Angola  2006             24.1
# 2                  Albania  2006             59.1
# 3     United Arab Emirates  2006             24.2
# 4                Argentina  2006             66.3
# ...                    ...   ...              ...
# 2500               Vietnam  2020             29.4
# 2501                 Yemen  2020             19.5
# 2502          South Africa  2020             70.5
# 2503                Zambia  2020             48.6
# 2504              Zimbabwe  2020             31.6
#
# [2505 rows x 3 columns]

# %%
democ_long.to_csv('long_democracy_ind.csv')

# %%
fg = pd.read_csv('./functioning_government.csv')

# %%
fg_long = pd.melt(fg, id_vars='country', var_name='year', value_name='index_of_functioning_goverment')
fg_long
# Out:
#                    country  year  index_of_functioning_goverment
# 0              Afghanistan  2006                             0.0
# 1                   Angola  2006                            21.4
# 2                  Albania  2006                            50.7
# 3     United Arab Emirates  2006                            30.7
# 4                Argentina  2006                            50.0
# ...                    ...   ...                             ...
# 2500               Vietnam  2020                            28.6
# 2501                 Yemen  2020                             0.0
# 2502          South Africa  2020                            71.4
# 2503                Zambia  2020                            29.3
# 2504              Zimbabwe  2020                            25.0
#
# [2505 rows x 3 columns]

# %%
fg_long.to_csv('long_functioning_goverment.csv')

# %%
pop = pd.read_csv('./population_WB.csv')
pop.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54208.0      55434.0
# 1  Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                  Afghanistan          AFG    8996967.0    9169406.0
# 3   Africa Western and Central          AFW   96396419.0   98407221.0
# 4                       Angola          AGO    5454938.0    5531451.0
#
#           1962         1963         1964         1965         1966  \
# 0      56234.0      56699.0      57029.0      57357.0      57702.0
# 1  137614644.0  141202036.0  144920186.0  148769974.0  152752671.0
# 2    9351442.0    9543200.0    9744772.0    9956318.0   10174840.0
# 3  100506960.0  102691339.0  104953470.0  107289875.0  109701811.0
# 4    5608499.0    5679409.0    5734995.0    5770573.0    5781305.0
#
#           1967  ...         2011         2012         2013         2014  \
# ...

# %%
pop.rename(columns={'Country Name': 'country', 'Country Code': 'code'}, inplace=True)

# %%
pop_long = pd.melt(pop, id_vars=['country', 'code'], var_name='year' , value_name='population')

# %%
pop_long
# Out:
#                            country code  year   population
# 0                            Aruba  ABW  1960      54208.0
# 1      Africa Eastern and Southern  AFE  1960  130836765.0
# 2                      Afghanistan  AFG  1960    8996967.0
# 3       Africa Western and Central  AFW  1960   96396419.0
# 4                           Angola  AGO  1960    5454938.0
# ...                            ...  ...   ...          ...
# 16221                       Kosovo  XKX  2020    1790133.0
# 16222                  Yemen, Rep.  YEM  2020   29825968.0
# 16223                 South Africa  ZAF  2020   59308690.0
# 16224                       Zambia  ZMB  2020   18383956.0
# 16225                     Zimbabwe  ZWE  2020   14862927.0
#
# [16226 rows x 4 columns]

# %%
wom = pd.read_csv('./women_in_parliament.csv')

# %%
wom_long = pd.melt(wom, id_vars='country', var_name='year', value_name='women_in_parliament_%')

# %%
wom_long
# Out:
#                     country  year  women_in_parliament_%
# 0               Afghanistan  1945                    NaN
# 1                    Angola  1945                    NaN
# 2                   Albania  1945                   3.66
# 3                   Andorra  1945                    NaN
# 4      United Arab Emirates  1945                    NaN
# ...                     ...   ...                    ...
# 14663                 Samoa  2020                  10.00
# 14664                 Yemen  2020                   0.97
# 14665          South Africa  2020                  45.40
# 14666                Zambia  2020                  16.80
# 14667              Zimbabwe  2020                  34.60
#
# [14668 rows x 3 columns]

# %%
wom_long.to_csv('long_wom_in_par.csv')

# %%
happy.drop(columns=['Unnamed: 0'], inplace=True)

# %%
happy
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 1           Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2217  Turkmenistan           Asia  2019       51.2
# 2218      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
happy.to_csv('long_happiness_score.csv')

# %%
happy['year'] = happy['year'].astype(str)
democ_long['year'] = democ_long['year'].astype(str)

# %%
merged_df = pd.merge(happy, democ_long, on=['country', 'year'], how='outer')
merged_df
# Out:
#            country continent  year  happiness  democracy_score
# 0          Algeria    Africa  2005        NaN              NaN
# 1           Turkey      Asia  2005       47.2              NaN
# 2            Benin    Africa  2005        NaN              NaN
# 3         Botswana    Africa  2005        NaN              NaN
# 4          Burundi    Africa  2005        NaN              NaN
# ...            ...       ...   ...        ...              ...
# 2704       Vietnam       NaN  2020        NaN             29.4
# 2705         Yemen       NaN  2020        NaN             19.5
# 2706  South Africa       NaN  2020        NaN             70.5
# 2707        Zambia       NaN  2020        NaN             48.6
# 2708      Zimbabwe       NaN  2020        NaN             31.6
#
# [2709 rows x 5 columns]

# %%
fg_long['year'] = fg_long['year'].astype(str)

# %%
merged_df2 = pd.merge(merged_df, fg_long, on=['country', 'year'], how='outer')
merged_df2
# Out:
#            country continent  year  happiness  democracy_score  \
# 0          Algeria    Africa  2005        NaN              NaN
# 1           Turkey      Asia  2005       47.2              NaN
# 2            Benin    Africa  2005        NaN              NaN
# 3         Botswana    Africa  2005        NaN              NaN
# 4          Burundi    Africa  2005        NaN              NaN
# ...            ...       ...   ...        ...              ...
# 2704       Vietnam       NaN  2020        NaN             29.4
# 2705         Yemen       NaN  2020        NaN             19.5
# 2706  South Africa       NaN  2020        NaN             70.5
# 2707        Zambia       NaN  2020        NaN             48.6
# 2708      Zimbabwe       NaN  2020        NaN             31.6
#
#       index_of_functioning_goverment
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# ...

# %%
pop_long['year'] = pop_long['year'].astype(str)

# %%
pop_long.to_csv('long_population.csv')

# %%
merged_df3 = pd.merge(merged_df2, pop_long, on=['country', 'year'], how='outer')
merged_df3
# Out:
#            country continent  year  happiness  democracy_score  \
# 0          Algeria    Africa  2005        NaN              NaN
# 1           Turkey      Asia  2005       47.2              NaN
# 2            Benin    Africa  2005        NaN              NaN
# 3         Botswana    Africa  2005        NaN              NaN
# 4          Burundi    Africa  2005        NaN              NaN
# ...            ...       ...   ...        ...              ...
# 16437      Vanuatu       NaN  2020        NaN              NaN
# 16438        World       NaN  2020        NaN              NaN
# 16439        Samoa       NaN  2020        NaN              NaN
# 16440       Kosovo       NaN  2020        NaN              NaN
# 16441  Yemen, Rep.       NaN  2020        NaN              NaN
#
#        index_of_functioning_goverment code    population
# 0                                 NaN  DZA  3.314972e+07
# 1                                 NaN  TUR  6.790346e+07
# ...

# %%
wom_long['year'] = wom_long['year'].astype(str)

# %%
merged_df4 = pd.merge(merged_df3, wom_long, on=['country', 'year'], how='outer')
merged_df4
# Out:
#         country continent  year  happiness  democracy_score  \
# 0       Algeria    Africa  2005        NaN              NaN
# 1        Turkey      Asia  2005       47.2              NaN
# 2         Benin    Africa  2005        NaN              NaN
# 3      Botswana    Africa  2005        NaN              NaN
# 4       Burundi    Africa  2005        NaN              NaN
# ...         ...       ...   ...        ...              ...
# 19954    Brunei       NaN  2018        NaN              NaN
# 19955   Bahamas       NaN  2019        NaN              NaN
# 19956    Brunei       NaN  2019        NaN              NaN
# 19957   Bahamas       NaN  2020        NaN              NaN
# 19958    Brunei       NaN  2020        NaN              NaN
#
#        index_of_functioning_goverment code  population  women_in_parliament_%
# 0                                 NaN  DZA  33149720.0                   8.96
# 1                                 NaN  TUR  67903461.0                   7.21
# ...

# %%
income = pd.read_csv('./average_daily_income.csv', sep=';')
income
# Out:
#                   country    1800    1801    1802    1803    1804    1805  \
# 0             Afghanistan  919.00  919.00  919.00  919.00  919.00  919.00
# 1                  Angola    2.27    2.27    2.28    2.29    2.30    2.31
# 2                 Albania    1.22    1.22    1.22    1.22    1.22    1.22
# 3                 Andorra    1.48    1.49    1.49    1.49    1.49    1.50
# 4    United Arab Emirates    2.90    2.91    2.92    2.93    2.94    2.95
# ..                    ...     ...     ...     ...     ...     ...     ...
# 190                 Samoa    2.76    2.76    2.76    2.76    2.76    2.76
# 191                 Yemen    1.22    1.23    1.23    1.23    1.24    1.24
# 192          South Africa    1.34    1.32    1.31    1.29    1.28    1.21
# 193                Zambia    1.26    1.26    1.27    1.27    1.27    1.27
# 194              Zimbabwe    1.94    1.94    1.94    1.94    1.95    1.95
#
#        1806    1807    1808  ...   2012   2013   2014   2015   2016   2017  \
# ...

# %%
inc_long = pd.melt(income, id_vars='country', var_name='year', value_name='daily_income_usd')
inc_long
# Out:
#                     country  year  daily_income_usd
# 0               Afghanistan  1800            919.00
# 1                    Angola  1800              2.27
# 2                   Albania  1800              1.22
# 3                   Andorra  1800              1.48
# 4      United Arab Emirates  1800              2.90
# ...                     ...   ...               ...
# 43285                 Samoa  2021              9.33
# 43286                 Yemen  2021              2.14
# 43287          South Africa  2021             10.30
# 43288                Zambia  2021              2.68
# 43289              Zimbabwe  2021              3.70
#
# [43290 rows x 3 columns]

# %%
inc_long['year'] = inc_long['year'].astype(str)

# %%
inc_long.to_csv('long_average_daily_inc.csv')

# %%
merged_df5 = pd.merge(merged_df4, inc_long, on=['country', 'year'], how='outer')
merged_df5
# Out:
#             country continent  year  happiness  democracy_score  \
# 0           Algeria    Africa  2005        NaN              NaN
# 1            Turkey      Asia  2005       47.2              NaN
# 2             Benin    Africa  2005        NaN              NaN
# 3          Botswana    Africa  2005        NaN              NaN
# 4           Burundi    Africa  2005        NaN              NaN
# ...             ...       ...   ...        ...              ...
# 48607         Samoa       NaN  2021        NaN              NaN
# 48608         Yemen       NaN  2021        NaN              NaN
# 48609  South Africa       NaN  2021        NaN              NaN
# 48610        Zambia       NaN  2021        NaN              NaN
# 48611      Zimbabwe       NaN  2021        NaN              NaN
#
#        index_of_functioning_goverment code  population  women_in_parliament_%  \
# 0                                 NaN  DZA  33149720.0                   8.96
# ...

# %%
income_inequlity = pd.read_csv('./income-inequality.csv', sep=';')
income_inequlity
# Out:
#                   country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0             Afghanistan  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5
# 1                  Angola  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7
# 2                 Albania  39.9  39.9  39.9  39.9  39.9  39.9  39.9  39.9
# 3                 Andorra  42.5  42.5  42.5  42.5  42.5  42.5  42.5  42.5
# 4    United Arab Emirates  39.8  39.8  39.8  39.8  39.8  39.8  39.8  39.7
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 192                 Samoa  40.7  40.7  40.7  40.7  40.7  40.7  40.7  40.7
# 193                 Yemen  49.8  49.8  49.8  49.8  49.8  49.8  49.8  49.8
# 194          South Africa  35.2  35.2  35.2  35.2  35.2  35.2  35.2  35.2
# 195                Zambia  52.1  52.1  52.1  52.1  52.1  52.1  52.1  52.1
# 196              Zimbabwe  27.3  27.3  27.3  27.3  27.3  27.3  27.3  27.3
#
#      1808  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
income_inequlity_long = pd.melt(income_inequlity, id_vars='country', var_name='year', value_name='income_inequlity')
income_inequlity_long
# Out:
#                     country  year  income_inequlity
# 0               Afghanistan  1800              30.5
# 1                    Angola  1800              57.7
# 2                   Albania  1800              39.9
# 3                   Andorra  1800              42.5
# 4      United Arab Emirates  1800              39.8
# ...                     ...   ...               ...
# 43729                 Samoa  2021              38.7
# 43730                 Yemen  2021              38.5
# 43731          South Africa  2021              64.9
# 43732                Zambia  2021              58.9
# 43733              Zimbabwe  2021              51.8
#
# [43734 rows x 3 columns]

# %%
income_inequlity_long.to_csv('long_income_inequlity.csv')

# %%
income_inequlity_long['year'] = income_inequlity_long['year'].astype(str)

# %%
merged_df6 = pd.merge(merged_df5, income_inequlity_long, on=['country', 'year'], how='outer')
merged_df6
# Out:
#              country continent  year  happiness  democracy_score  \
# 0            Algeria    Africa  2005        NaN              NaN
# 1             Turkey      Asia  2005       47.2              NaN
# 2              Benin    Africa  2005        NaN              NaN
# 3           Botswana    Africa  2005        NaN              NaN
# 4            Burundi    Africa  2005        NaN              NaN
# ...              ...       ...   ...        ...              ...
# 48975       Holy See       NaN  2018        NaN              NaN
# 48976       Holy See       NaN  2019        NaN              NaN
# 48977       Holy See       NaN  2020        NaN              NaN
# 48978       Holy See       NaN  2021        NaN              NaN
# 48979  Liechtenstein       NaN  2021        NaN              NaN
#
#        index_of_functioning_goverment code  population  women_in_parliament_%  \
# 0                                 NaN  DZA  33149720.0                   8.96
# ...

# %%
merged_df6['year'].unique()
# Out:
# array(['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '1945', '1946', '1947',
#        '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955',
#        '1956', '1957', '1958', '1959', '1800', '1801', '1802', '1803',
#        '1804', '1805', '1806', '1807', '1808', '1809', '1810', '1811',
#        '1812', '1813', '1814', '1815', '1816', '1817', '1818', '1819',
#        '1820', '1821', '1822', '1823', '1824', '1825', '1826', '1827',
# ...

# %%
merged_df6.to_csv('all_data_merged.csv')

# %%
merged_df6
# Out:
#              country continent  year  happiness  democracy_score  \
# 0            Algeria    Africa  2005        NaN              NaN
# 1             Turkey      Asia  2005       47.2              NaN
# 2              Benin    Africa  2005        NaN              NaN
# 3           Botswana    Africa  2005        NaN              NaN
# 4            Burundi    Africa  2005        NaN              NaN
# ...              ...       ...   ...        ...              ...
# 48975       Holy See       NaN  2018        NaN              NaN
# 48976       Holy See       NaN  2019        NaN              NaN
# 48977       Holy See       NaN  2020        NaN              NaN
# 48978       Holy See       NaN  2021        NaN              NaN
# 48979  Liechtenstein       NaN  2021        NaN              NaN
#
#        index_of_functioning_goverment code  population  women_in_parliament_%  \
# 0                                 NaN  DZA  33149720.0                   8.96
# ...
