# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ratings = pd.read_csv('./all_airways_rating.csv')

# %%
ratings.head()
# Out:
#    Unnamed: 0   Airline Name Overall_Rating  \
# 0           0    AB Aviation              9
# 1           1    AB Aviation              1
# 2           2    AB Aviation              1
# 3           3  Adria Airways              1
# 4           4  Adria Airways              1
#
#                             Review_Title          Review Date  Verified  \
# 0                "pretty decent airline"   11th November 2019      True
# 1                   "Not a good airline"       25th June 2019      True
# 2         "flight was fortunately short"       25th June 2019      True
# 3    "I will never fly again with Adria"  28th September 2019     False
# 4  "it ruined our last days of holidays"  24th September 2019      True
#
#                                               Review       Aircraft  \
# 0    Moroni to Moheli. Turned out to be a pretty ...            NaN
# 1   Moroni to Anjouan. It is a very small airline...           E120
# 2    Anjouan to Dzaoudzi. A very small airline an...  Embraer E120
# 3    Please do a favor yourself and do not fly wi...            NaN
# 4   Do not book a flight with this airline! My fr...            NaN
#
#   Type Of Traveller      Seat Type                             Route  \
# 0      Solo Leisure  Economy Class                  Moroni to Moheli
# 1      Solo Leisure  Economy Class                 Moroni to Anjouan
# 2      Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3      Solo Leisure  Economy Class             Frankfurt to Pristina
# 4    Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
#
#   Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0     Nov-19           4.0                  5.0               4.0
# 1     Jun-19           2.0                  2.0               1.0
# 2     Jun-19           2.0                  1.0               1.0
# 3     Sep-19           1.0                  1.0               NaN
# 4     Sep-19           1.0                  1.0               1.0
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0             4.0                     NaN                  NaN
# 1             1.0                     NaN                  NaN
# 2             1.0                     NaN                  NaN
# 3             1.0                     NaN                  NaN
# 4             1.0                     1.0                  1.0
#
#    Value For Money Recommended
# 0              3.0         yes
# 1              2.0          no
# 2              2.0          no
# 3              1.0          no
# 4              1.0          no

# %% [markdown]
# ### Filtering needed airlines

# %%
ratings['Airline Name'].unique()
# Out:
# array(['AB Aviation', 'Adria Airways', 'Aegean Airlines', 'Aer Lingus',
#        'Aero VIP', 'Aerocaribbean', 'Aeroflot Russian Airlines',
#        'AeroItalia', 'Aerolineas Argentinas', 'Aeromar', 'Aeromexico',
#        'Aerosur', 'Africa World Airlines', 'Afriqiyah Airways',
#        'Aigle Azur', 'Air Algerie', 'Air Antilles', 'Air Arabia',
#        'Air Astana', 'Air Austral', 'Air Bagan', 'Air Berlin',
#        'Air Botswana', 'Air Burkina', 'Air Busan', 'Air Cairo',
#        'Air Canada', 'Air Canada rouge', 'Air Caraibes', 'Air China',
#        'Air Corsica', 'Air Costa', "Air Cote d'Ivoire", 'Air Djibouti',
#        'Air Dolomiti', 'Air Europa', 'Air France', 'Air Greenland',
#        'Air Iceland Connect', 'Air India', 'Air India Express',
#        'Air Italy', 'Air Juan', 'Air KBZ', 'Air Koryo', 'Air Labrador',
#        'Air Macau', 'Air Madagascar', 'Air Malawi', 'Air Malta',
#        'Air Mauritius', 'Air Mediterranee', 'Air Memphis', 'Air Moldova',
#        'Air Namibia', 'Air New Zealand', 'Air Niugini',
#        "Air North Yukon's Airline", 'Air Nostrum', 'Air Panama',
#        'Air Pegasus', 'Air Rarotonga', 'Air Serbia', 'Air Seychelles',
#        'Air Tahiti Nui', 'Air Tanzania', 'Air Transat', 'Air Zimbabwe',
#        'AirAsia', 'AirAsia India', 'AirAsia Philippines', 'AirAsia X',
#        'AirAsia Zest', 'airBaltic', 'Aircalin', 'Airlink', 'Airnorth',
#        'AirSWIFT', 'Akasa Air', 'Alaska Airlines', 'Alitalia',
#        'Allegiant Air', 'Alliance Air', 'Alliance Airlines', 'Amaszonas',
#        'American Airlines', 'American Eagle', 'ANA All Nippon Airways',
#        'AnadoluJet', 'Andes Líneas Aéreas', 'Ariana Afghan Airlines',
#        'Arik Air', 'Arkefly', 'Armenia Air Company', 'Asiana Airlines',
#        'ASKY Airlines', 'ATA Airlines', 'Atlantic Airways', 'Auric Air',
#        'Aurigny Air', 'Austrian Airlines', 'Avelo Airlines', 'Avianca',
#        'Avior Airlines', 'Azerbaijan Airlines', 'Azur Air Germany',
#        'BA CityFlyer', 'Badr Airlines', 'Bahamasair', 'Bamboo Airways',
#        'Bangkok Airways', 'Bassaka Air', 'Batik Air',
#        'Beijing Capital Airlines', 'Belavia', 'Berjaya Air',
#        'Bhutan Airlines', 'Binter Canarias', 'Blue Air', 'Blue Islands',
#        'Blue Panorama Airlines', 'Blue1', 'Bluebird Airways',
#        'bmi Regional', 'BoraJet', 'Boutique Air', 'Breeze Airways',
#        'British Airways', 'Brussels Airlines', 'Buddha Air',
#        'Bulgaria Air', 'Buta Airways', 'Camair-Co', 'Cambodia Airways',
#        'Cambodia Bayon Airlines', 'Canadian North', 'Canaryfly',
#        'Cape Air', 'Caribbean Airlines', 'Carpatair', 'Cathay Dragon',
#        'Cathay Pacific Airways', 'Cayman Airways', 'Cebu Pacific',
#        'CemAir', 'Central Mountain Air', 'China Airlines',
#        'China Eastern Airlines', 'China Southern Airlines',
#        'China United Airlines', 'Citilink', 'CityJet', 'Coastal Aviation',
#        'Cobalt', 'Comair', 'Condor Airlines', 'Conviasa', 'Copa Airlines',
#        'Corendon Airlines', 'Corsair', 'Croatia Airlines',
#        'CSA Czech Airlines', 'Cubana Airlines', 'Cyprus Airways',
#        'Delta Air Lines', 'Dimonim Air', 'Dniproavia', 'Dragonair',
#        'Druk Air', 'Dynamic International Airways', 'Eastern Airlines',
#        'Eastern Airways', 'Easyfly', 'easyJet', 'Edelweiss Air',
#        'Egyptair', 'El Al Israel Airlines', 'Ellinair', 'Emirates',
#        'Eritrean Airlines', 'Ernest Airlines', 'Estonian Air',
#        'Eswatini Air', 'Ethiopian Airlines', 'Etihad Airways',
#        'euroAtlantic Airways', 'Europe Airpost', 'Eurowings', 'EVA Air',
#        'Evelop Airlines', 'EWA Air', 'Ravn Alaska', 'fastjet',
#        'Felix Airways', 'Fiji Airways', 'Finnair', 'Firefly',
#        'Flair Airlines', 'Fly540.com', 'flyadeal', 'FlyArystan', 'flybe',
#        'flydubai', 'Flynas', 'FLYONE', 'FlySafair', 'FMI Air',
#        'French Bee', 'Frontier Airlines', 'Garuda Indonesia',
#        'Georgian Airways', 'Germania Airline', 'Germanwings', 'Go First',
#        'GoAir', 'Golden Myanmar Airlines', 'Grand Cru Airlines',
#        'Greater Bay Airlines', 'Gulf Air', 'Hainan Airlines',
#        'Hawaiian Airlines', 'Henan Airlines', 'Hi Fly',
#        'Himalaya Airlines', 'HiSky', 'Hong Kong Airlines', 'HOP!',
#        'Horizon Air', 'Hunnu Air', 'Iberia', 'Iberia Express', 'Iberojet',
#        'Icelandair', 'Insel Air', 'Intercaribbean Airways', 'Interjet',
#        'InterSky', 'Iran Air', 'Iraqi Airways', 'Israir Airlines',
#        'ITA Airways', 'Japan Airlines', 'Jazeera Airways', 'Jazz',
#        'JC International Airlines', 'Jeju Air', 'Jet Airways', 'Jet2.com',
#        'Jetairfly', 'Jetblue Airways', 'JetSmart', 'Jetstar Airways',
#        'Jetstar Asia', 'Jetstar Japan', 'Jetstar Pacific', 'JetsuiteX',
#        'Jin Air', 'Joon', 'Jordan Aviation', 'Kam Air', 'Kan Air',
#        'Karthago Airlines', 'KD Air', 'Kenya Airways',
#        'KLM Royal Dutch Airlines', 'Korean Air', 'Kulula',
#        'Kuwait Airways', 'La Compagnie', 'LAN Airlines', 'LAN Colombia',
#        'LAN Peru', 'Lao Airlines', 'LATAM Airlines', 'Laudamotion',
#        'LC Perú', 'Level', 'LIAT', 'Libyan Airlines', 'Lion Air',
#        'Loch Lomond Seaplanes', 'Loganair', 'LOT Polish Airlines',
#        'Lubeck Air', 'Lucky Air', 'Lufthansa', 'Luxair', 'Lynx Air',
#        'Mack Air', 'Madagasikara Airways', 'Mahan Air',
#        'Malawian Airlines', 'Malaysia Airlines', 'Maldivian',
#        'Malindo Air', 'Mandarin Airlines', 'Mann Yadanarpon Airlines',
#        'Manta Air', 'Martinair', 'Mauritania Airlines', 'Maya Island Air',
#        'MAYAir', 'MEGA Maldives Airlines', 'Meridiana', 'Mihin Lanka',
#        'Mokulele Airlines', 'Moldavian Airlines', 'Monarch Airlines',
#        'Montenegro Airlines', 'Motor Sich Airlines', 'Myanmar Airways',
#        'Myanmar National Airlines', 'NAM Air', 'Nature Air',
#        'Nauru Airlines', 'Nepal Airlines', 'NextJet', 'NIKI', 'Nile Air',
#        'Nok Air', 'NokScoot', 'Nordavia', 'Nordic Regional Airlines',
#        'Nordica', 'NordStar', 'Nordwind Airlines',
#        'Norse Atlantic Airways', 'Norwegian', 'Nouvelair', 'Novair',
#        'Novoair', 'Okay Airways', 'Olympic Air', 'Oman Air',
#        'Omni Air International', 'Onur Air', 'Openskies',
#        'Pacific Airlines', 'PAL Express', 'Pan Pacific Airlines',
#        'Passion Air', 'PAWA Dominicana', 'Peach Aviation',
#        'Pegasus Airlines', 'PenAir', 'Peruvian Airlines',
#        'Petroleum Air Services', 'Philippine Airlines', 'Phuket Air',
#        'PLAY', 'Pobeda Airlines', 'Porter Airlines', 'Primera Air',
#        'Privilege Style', 'Qantas Airways', 'QantasLink', 'Qatar Airways',
#        'Qazaq Air', 'Red Wings Airlines', 'Regent Airways',
#        'Regional Express', 'Rex Airlines', 'Rhein-Neckar Air',
#        'Rossiya Airlines', 'Royal Air Maroc', 'Royal Brunei Airlines',
#        'Royal Jordanian Airlines', 'Rwandair', 'Ryanair',
#        'S7 Siberia Airlines', 'SA Express', 'Safarilink', 'Safi Airways',
#        'Salam Air', 'Sansa Airlines', 'SATA Air Azores', 'SATENA',
#        'Saudi Arabian Airlines', 'SCAT Airlines', 'Scoot',
#        'Seaborne Airlines', 'SereneAir', 'Shaheen Air',
#        'Shandong Airlines', 'Shanghai Airlines', 'Shenzhen Airlines',
#        'Sichuan Airlines', 'SilkAir', 'Silver Airways',
#        'Singapore Airlines', 'Sky Airline', 'Sky Express Airlines',
#        'Skybus', 'Skymark Airlines', 'Skytrans Airlines',
#        'SkyUp Airlines', 'SkyWest Airlines', 'SkyWork Airlines',
#        'Smartavia', 'SmartLynx Airlines', 'SmartWings',
#        'Sol Líneas Aéreas', 'Solomon Airlines', 'Somon Air',
#        'South African Airways', 'Southwest Airlines', 'SpiceJet',
#        'Spirit Airlines', 'SriLankan Airlines', 'Sriwijaya Air',
#        'StarFlyer', 'Sudan Airways', 'Sun Country Airlines', 'Sun-Air',
#        'Sunwing Airlines', 'Suparna Airlines', 'Super Air Jet',
#        'Surinam Airways', 'SVG Air', 'Swoop', 'SyrianAir', "T'Way Air",
#        'TAAG Angola Airlines', 'TACA Regional', 'TAG Airlines',
#        'Tailwind Airlines', 'TAM Airlines', 'TAME',
#        'Tame Línea Aérea Del Ecuador', 'TAP Portugal', 'TAR Aerolineas',
#        'Thai AirAsia', 'Thai Airways', 'Thai Lion Air',
#        'Thai Smile Airways', 'Thomas Cook Airlines',
#        'Thomas Cook Airlines Scandinavia', 'Thomson Airways',
#        'Tianjin Airlines', 'Tibet Airlines', 'Tigerair',
#        'Tigerair Australia', 'Tigerair Taiwan', 'Titan Airways',
#        'Transaero Airlines', 'TransAsia Airways', 'Transavia',
#        'TransNusa', 'Trigana Air', 'Tropic Air Belize', 'TUI Airways',
#        'TUIfly', 'TUIfly Nordic', 'Tunisair', 'Turkish Airlines',
#        'Turkmenistan Airlines', 'TUS Airways', 'Uganda Airlines',
#        'Ultra Air', 'United Airlines', 'UP by El Al', 'Ural Airlines',
#        'US Airways', 'US-Bangla Airlines', 'Utair Aviation',
#        'Uzbekistan Airways', 'V Air', 'Vanilla Air', 'ViaAir',
#        'Vietnam Airlines', 'Virgin America', 'Virgin Australia',
#        'Vistara', 'Viva Air', 'VivaAerobús', 'VivaColombia',
#        'VLM Airlines', 'Volaris', 'Volotea', 'Voyage Air',
#        'Vueling Airlines', 'Wamos Air', 'Wideroe', 'Winair', 'Wingo',
#        'Wings Air', 'Wizz Air', 'World2Fly', 'WOW air', 'Xiamen Airlines',
#        'XL Airways France', 'Yakutia Airlines', 'Yangon Airways',
#        'Yemenia', 'Yeti Airlines', 'Zambia Airways', 'ZIPAIR'],
#       dtype=object)

# %%
airline_names = ['British Airways', 'Emirates', 'easyJet', 'Jet2.com', 'TUI Airways']
df = ratings[ratings['Airline Name'].isin(airline_names)]
df.head()
# Out:
#       Unnamed: 0     Airline Name Overall_Rating  \
# 6019        6019  British Airways              1
# 6020        6020  British Airways              2
# 6021        6021  British Airways              1
# 6022        6022  British Airways              1
# 6023        6023  British Airways              1
#
#                              Review_Title     Review Date  Verified  \
# 6019          "lives in their past glory"  26th July 2023      True
# 6020  "Check-in Desk rude and dismissive"  26th July 2023      True
# 6021               "All in all, terrible"  25th July 2023      True
# 6022      "cancelled the rebooked flight"  24th July 2023     False
# 6023             "Zero empathy was shown"  21st July 2023      True
#
#                                                  Review Aircraft  \
# 6019   An airline that lives in their past glory and...     A321
# 6020    Check-in Desk rude and dismissive. Flight la...      NaN
# 6021   I chose British Airways especially because I ...      NaN
# 6022   I booked Premium Economy from INV to LAX (via...      NaN
# 6023   A simple story with an unfortunate outcome th...      NaN
#
#      Type Of Traveller        Seat Type                                Route  \
# 6019    Family Leisure   Business Class                     Madrid to London
# 6020    Family Leisure    Economy Class                    Rhodes to Gatwick
# 6021    Family Leisure    Economy Class                  Barcelona to London
# 6022    Couple Leisure  Premium Economy  Inverness to Los Angeles via London
# 6023    Couple Leisure    Economy Class     London City Airport to Frankfurt
#
#      Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 6019     Jul-23           1.0                  1.0               NaN
# 6020     Jul-23           2.0                  3.0               1.0
# 6021     Jul-23           1.0                  4.0               1.0
# 6022     Nov-22           NaN                  NaN               NaN
# 6023     Jul-23           3.0                  3.0               NaN
#
#       Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 6019             1.0                     NaN                  NaN
# 6020             1.0                     1.0                  1.0
# 6021             1.0                     1.0                  1.0
# 6022             NaN                     NaN                  NaN
# 6023             1.0                     NaN                  NaN
#
#       Value For Money Recommended
# 6019              1.0          no
# 6020              2.0          no
# 6021              1.0          no
# 6022              1.0          no
# 6023              1.0          no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 473 entries, 6019 to 21010
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              473 non-null    int64
#  1   Airline Name            473 non-null    object
#  2   Overall_Rating          473 non-null    object
#  3   Review_Title            473 non-null    object
#  4   Review Date             473 non-null    object
#  5   Verified                473 non-null    bool
#  6   Review                  473 non-null    object
#  7   Aircraft                208 non-null    object
#  8   Type Of Traveller       473 non-null    object
#  9   Seat Type               473 non-null    object
#  10  Route                   471 non-null    object
#  11  Date Flown              473 non-null    object
#  12  Seat Comfort            444 non-null    float64
#  13  Cabin Staff Service     442 non-null    float64
#  14  Food & Beverages        343 non-null    float64
#  15  Ground Service          458 non-null    float64
#  16  Inflight Entertainment  235 non-null    float64
#  17  Wifi & Connectivity     168 non-null    float64
#  18  Value For Money         473 non-null    float64
#  19  Recommended             473 non-null    object
# dtypes: bool(1), float64(7), int64(1), object(11)
# memory usage: 74.4+ KB

# %%
#df.to_csv('5airways.csv')

# %%
df = pd.read_csv('./5airways.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     Airline Name  Overall_Rating  \
# 0          6019        6019  British Airways               1
# 1          6020        6020  British Airways               2
# 2          6021        6021  British Airways               1
# 3          6022        6022  British Airways               1
# 4          6023        6023  British Airways               1
#
#                           Review_Title     Review Date  Verified  \
# 0          "lives in their past glory"  26th July 2023      True
# 1  "Check-in Desk rude and dismissive"  26th July 2023      True
# 2               "All in all, terrible"  25th July 2023      True
# 3      "cancelled the rebooked flight"  24th July 2023     False
# 4             "Zero empathy was shown"  21st July 2023      True
#
#                                               Review Aircraft  \
# 0   An airline that lives in their past glory and...     A321
# 1    Check-in Desk rude and dismissive. Flight la...      NaN
# 2   I chose British Airways especially because I ...      NaN
# 3   I booked Premium Economy from INV to LAX (via...      NaN
# 4   A simple story with an unfortunate outcome th...      NaN
#
#   Type Of Traveller  ...                                Route Date Flown  \
# 0    Family Leisure  ...                     Madrid to London     Jul-23
# 1    Family Leisure  ...                    Rhodes to Gatwick     Jul-23
# 2    Family Leisure  ...                  Barcelona to London     Jul-23
# 3    Couple Leisure  ...  Inverness to Los Angeles via London     Nov-22
# 4    Couple Leisure  ...     London City Airport to Frankfurt     Jul-23
#
#   Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0          1.0                  1.0               NaN             1.0
# 1          2.0                  3.0               1.0             1.0
# 2          1.0                  4.0               1.0             1.0
# 3          NaN                  NaN               NaN             NaN
# 4          3.0                  3.0               NaN             1.0
#
#    Inflight Entertainment  Wifi & Connectivity  Value For Money  Recommended
# 0                     NaN                  NaN              1.0           no
# 1                     1.0                  1.0              2.0           no
# 2                     1.0                  1.0              1.0           no
# 3                     NaN                  NaN              1.0           no
# 4                     NaN                  NaN              1.0           no
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0.1            473 non-null    int64
#  1   Unnamed: 0              473 non-null    int64
#  2   Airline Name            473 non-null    object
#  3   Overall_Rating          473 non-null    int64
#  4   Review_Title            473 non-null    object
#  5   Review Date             473 non-null    object
#  6   Verified                473 non-null    bool
#  7   Review                  473 non-null    object
#  8   Aircraft                208 non-null    object
#  9   Type Of Traveller       473 non-null    object
#  10  Seat Type               473 non-null    object
#  11  Route                   471 non-null    object
#  12  Date Flown              473 non-null    object
#  13  Seat Comfort            444 non-null    float64
#  14  Cabin Staff Service     442 non-null    float64
#  15  Food & Beverages        343 non-null    float64
#  16  Ground Service          458 non-null    float64
#  17  Inflight Entertainment  235 non-null    float64
#  18  Wifi & Connectivity     168 non-null    float64
#  19  Value For Money         473 non-null    float64
#  20  Recommended             473 non-null    object
# dtypes: bool(1), float64(7), int64(3), object(10)
# memory usage: 74.5+ KB

# %%
df.describe().T
# Out:
#                         count          mean          std     min     25%  \
# Unnamed: 0.1            473.0  10679.496829  4832.096415  6019.0  8270.0
# Unnamed: 0              473.0  10679.496829  4832.096415  6019.0  8270.0
# Overall_Rating          473.0      2.723044     2.673124     1.0     1.0
# Seat Comfort            444.0      2.700450     1.463753     1.0     1.0
# Cabin Staff Service     442.0      3.004525     1.632987     1.0     1.0
# Food & Beverages        343.0      2.655977     1.503801     1.0     1.0
# Ground Service          458.0      2.451965     1.629490     1.0     1.0
# Inflight Entertainment  235.0      2.514894     1.586128     1.0     1.0
# Wifi & Connectivity     168.0      1.595238     1.179861     1.0     1.0
# Value For Money         473.0      2.503171     1.599951     1.0     1.0
#
#                            50%       75%      max
# Unnamed: 0.1            8702.0  12122.00  21010.0
# Unnamed: 0              8702.0  12122.00  21010.0
# Overall_Rating             1.0      4.00      9.0
# Seat Comfort               3.0      4.00      5.0
# Cabin Staff Service        3.0      5.00      5.0
# Food & Beverages           3.0      4.00      5.0
# Ground Service             2.0      4.00      5.0
# Inflight Entertainment     2.0      4.00      5.0
# Wifi & Connectivity        1.0      1.25      5.0
# Value For Money            2.0      4.00      5.0

# %%
columns_to_drop = ['Unnamed: 0.1', 'Unnamed: 0','Review_Title','Review Date','Verified','Review','Aircraft','Type Of Traveller','Route','Date Flown',
                             ]

# %%
df.drop(columns=columns_to_drop, inplace=True)
df.head()
# Out:
#       Airline Name  Overall_Rating        Seat Type  Seat Comfort  \
# 0  British Airways               1   Business Class           1.0
# 1  British Airways               2    Economy Class           2.0
# 2  British Airways               1    Economy Class           1.0
# 3  British Airways               1  Premium Economy           NaN
# 4  British Airways               1    Economy Class           3.0
#
#    Cabin Staff Service  Food & Beverages  Ground Service  \
# 0                  1.0               NaN             1.0
# 1                  3.0               1.0             1.0
# 2                  4.0               1.0             1.0
# 3                  NaN               NaN             NaN
# 4                  3.0               NaN             1.0
#
#    Inflight Entertainment  Wifi & Connectivity  Value For Money Recommended
# 0                     NaN                  NaN              1.0          no
# 1                     1.0                  1.0              2.0          no
# 2                     1.0                  1.0              1.0          no
# 3                     NaN                  NaN              1.0          no
# 4                     NaN                  NaN              1.0          no

# %% [markdown]
# ### Making value for money table

# %%
average_value_for_money = df.groupby('Airline Name')['Value For Money'].mean()
value_for_money = pd.DataFrame({'Airline Name': average_value_for_money.index, 'Average Value For Money': average_value_for_money.values})
value_for_money.set_index('Airline Name', inplace=True)

# %%
value_for_money
# Out:
#                  Average Value For Money
# Airline Name
# British Airways                 1.810000
# Emirates                        2.560000
# Jet2.com                        3.270000
# TUI Airways                     3.054795
# easyJet                         1.970000

# %%
#value_for_money.to_csv('value_for_money.csv')

# %%
column_to_avg = ['Overall_Rating']
average_rating = df.groupby('Airline Name')[column_to_avg].mean()
average_rating
# Out:
#                  Overall_Rating
# Airline Name
# British Airways        2.400000
# Emirates               3.230000
# Jet2.com               2.760000
# TUI Airways            3.643836
# easyJet                1.830000

# %%
column_to_avg = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Ground Service', 'Inflight Entertainment', 'Wifi & Connectivity', 'Value For Money']
average_ratings = df.groupby('Airline Name')[columns_to_avg].mean()
average_ratings
# Out:
#                  Overall_Rating
# Airline Name
# British Airways        2.400000
# Emirates               3.230000
# Jet2.com               2.760000
# TUI Airways            3.643836
# easyJet                1.830000

# %% [markdown]
# ### Checking recommendations

# %%
reviews_count = df['Airline Name'].value_counts()
reviews_count
# Out:
# Airline Name
# British Airways    100
# easyJet            100
# Emirates           100
# Jet2.com           100
# TUI Airways         73
# Name: count, dtype: int64

# %% [markdown]
# ### Making table for heatmap 'services'

# %%
df
# Out:
#         Airline Name  Overall_Rating        Seat Type  Seat Comfort  \
# 0    British Airways               1   Business Class           1.0
# 1    British Airways               2    Economy Class           2.0
# 2    British Airways               1    Economy Class           1.0
# 3    British Airways               1  Premium Economy           NaN
# 4    British Airways               1    Economy Class           3.0
# ..               ...             ...              ...           ...
# 468      TUI Airways               1    Economy Class           1.0
# 469      TUI Airways               8    Economy Class           4.0
# 470      TUI Airways               1    Economy Class           4.0
# 471      TUI Airways               9    Economy Class           4.0
# 472      TUI Airways               3  Premium Economy           3.0
#
#      Cabin Staff Service  Food & Beverages  Ground Service  \
# 0                    1.0               NaN             1.0
# 1                    3.0               1.0             1.0
# 2                    4.0               1.0             1.0
# 3                    NaN               NaN             NaN
# 4                    3.0               NaN             1.0
# ..                   ...               ...             ...
# 468                  2.0               1.0             3.0
# 469                  5.0               4.0             5.0
# 470                  5.0               NaN             4.0
# 471                  5.0               3.0             5.0
# 472                  2.0               4.0             1.0
#
#      Inflight Entertainment  Wifi & Connectivity  Value For Money Recommended
# 0                       NaN                  NaN              1.0          no
# 1                       1.0                  1.0              2.0          no
# 2                       1.0                  1.0              1.0          no
# 3                       NaN                  NaN              1.0          no
# 4                       NaN                  NaN              1.0          no
# ..                      ...                  ...              ...         ...
# 468                     1.0                  NaN              1.0          no
# 469                     4.0                  NaN              5.0         yes
# 470                     NaN                  NaN              4.0         yes
# 471                     NaN                  NaN              4.0         yes
# 472                     1.0                  NaN              2.0          no
#
# [473 rows x 11 columns]

# %%
services_columns = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Ground Service', 
                    'Inflight Entertainment', 'Wifi & Connectivity', 'Value For Money']
services_and_value_df = df[['Airline Name'] + services_columns]

# %%
average_values = services_and_value_df.groupby('Airline Name').mean()
average_values.reset_index(inplace=True)

# %%
average_values
# Out:
#       Airline Name  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0  British Airways      2.446809             2.765957          2.259259
# 1         Emirates      2.968750             2.926316          2.900000
# 2         Jet2.com      3.139785             3.645161          2.970149
# 3      TUI Airways      2.902778             3.458333          2.875000
# 4          easyJet      2.056180             2.295455          2.183673
#
#    Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0        2.061856                2.474576             1.695652
# 1        2.632653                3.400000             1.927273
# 2        3.221053                1.166667             1.478261
# 3        2.643836                2.548387             1.333333
# 4        1.747368                1.032258             1.062500
#
#    Value For Money
# 0         1.810000
# 1         2.560000
# 2         3.270000
# 3         3.054795
# 4         1.970000

# %%
service_categories = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
                      'Ground Service', 'Inflight Entertainment',
                      'Wifi & Connectivity', 'Value For Money']

# Initialize an empty list to store data for the new DataFrame
new_data = []

# Iterate through each service category
for service in service_categories:
    # Group by 'Airline Name' and calculate the mean value for the service category
    service_data = df.groupby('Airline Name')[service].mean().reset_index()
    
    # Rename the columns for consistency
    service_data.rename(columns={service: 'Value'}, inplace=True)
    
    # Add the service category column
    service_data['Service'] = service
    
    # Append the service data to the new_data list
    new_data.append(service_data)

# Concatenate the data from the list into a new DataFrame
new_df = pd.concat(new_data, ignore_index=True)

# %%
new_df
# Out:
#        Airline Name     Value                 Service
# 0   British Airways  2.446809            Seat Comfort
# 1          Emirates  2.968750            Seat Comfort
# 2          Jet2.com  3.139785            Seat Comfort
# 3       TUI Airways  2.902778            Seat Comfort
# 4           easyJet  2.056180            Seat Comfort
# 5   British Airways  2.765957     Cabin Staff Service
# 6          Emirates  2.926316     Cabin Staff Service
# 7          Jet2.com  3.645161     Cabin Staff Service
# 8       TUI Airways  3.458333     Cabin Staff Service
# 9           easyJet  2.295455     Cabin Staff Service
# 10  British Airways  2.259259        Food & Beverages
# 11         Emirates  2.900000        Food & Beverages
# 12         Jet2.com  2.970149        Food & Beverages
# 13      TUI Airways  2.875000        Food & Beverages
# 14          easyJet  2.183673        Food & Beverages
# 15  British Airways  2.061856          Ground Service
# 16         Emirates  2.632653          Ground Service
# 17         Jet2.com  3.221053          Ground Service
# 18      TUI Airways  2.643836          Ground Service
# 19          easyJet  1.747368          Ground Service
# 20  British Airways  2.474576  Inflight Entertainment
# 21         Emirates  3.400000  Inflight Entertainment
# 22         Jet2.com  1.166667  Inflight Entertainment
# 23      TUI Airways  2.548387  Inflight Entertainment
# 24          easyJet  1.032258  Inflight Entertainment
# 25  British Airways  1.695652     Wifi & Connectivity
# 26         Emirates  1.927273     Wifi & Connectivity
# 27         Jet2.com  1.478261     Wifi & Connectivity
# 28      TUI Airways  1.333333     Wifi & Connectivity
# 29          easyJet  1.062500     Wifi & Connectivity
# 30  British Airways  1.810000         Value For Money
# 31         Emirates  2.560000         Value For Money
# 32         Jet2.com  3.270000         Value For Money
# 33      TUI Airways  3.054795         Value For Money
# 34          easyJet  1.970000         Value For Money

# %%
#new_df.to_csv('compare_service_ratings_5airlines.csv')

# %% [markdown]
# ### Visualizations

# %%
plt.figure(figsize=(12, 6))

sns.barplot(data=average_ratings.reset_index(), x='Airline Name', y='Value For Money')

plt.xlabel('Airline Name')
plt.ylabel('Average Rating')
plt.title('Average Value For Money Rating by Airline')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.barplot(data=average_rating.reset_index(), x='Airline Name', y='Overall_Rating')

plt.xlabel('Airline Name')
plt.ylabel('Overall_Rating')
plt.title('Average Overall_Rating by Airline')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Airline Name', hue='Recommended', palette='Set1')

plt.xlabel('Airline Name')
plt.ylabel('Count')
plt.title('Recommended Count by Airline')

plt.xticks(rotation=45, ha='right')
plt.legend(title='Recommended')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

pivot_table = df.pivot_table(index='Airline Name', values=columns_to_avg)
sns.heatmap(data=pivot_table, annot=True, cmap='YlGnBu', center=0)

plt.title('Heatmap: Airline vs. Average Ratings')

plt.tight_layout()
plt.show()
