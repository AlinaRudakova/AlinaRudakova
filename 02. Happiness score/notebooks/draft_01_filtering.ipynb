# %%
import pandas as pd

# %%
democ = pd.read_csv('./democracy.csv')

# %%
democ.head()
# Out:
#                 country  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# 0           Afghanistan  30.6  30.4  30.2  27.5  24.8  24.8  24.8  24.8  27.7
# 1                Angola  24.1  28.8  33.5  33.4  33.2  33.2  33.5  33.5  33.5
# 2               Albania  59.1  59.1  59.1  58.9  58.6  58.1  56.7  56.7  56.7
# 3  United Arab Emirates  24.2  25.1  26.0  25.6  25.2  25.8  25.8  25.2  26.4
# 4             Argentina  66.3  66.3  66.3  67.3  68.4  68.4  68.4  68.4  68.4
#
#    2015  2016  2017  2018  2019  2020
# 0  27.7  25.5  25.5  29.7  28.5  28.5
# 1  33.5  34.0  36.2  36.2  37.2  36.6
# 2  59.1  59.1  59.8  59.8  58.9  60.8
# 3  27.5  27.5  26.9  27.6  27.6  27.0
# 4  70.2  69.6  69.6  70.2  70.2  69.5

# %%
fg = pd.read_csv('./functioning_government.csv')

# %%
fg.head()
# Out:
#                 country  2006   2007  2008  2009  2010  2011  2012  2013  \
# 0           Afghanistan   0.0   3.95   7.9   7.9   7.9   7.9   7.9   7.9
# 1                Angola  21.4  26.80  32.1  32.1  32.1  32.1  32.1  32.1
# 2               Albania  50.7  50.70  50.7  50.7  50.7  47.1  40.0  40.0
# 3  United Arab Emirates  30.7  35.00  39.3  37.5  35.7  35.7  35.7  35.7
# 4             Argentina  50.0  50.00  50.0  53.5  57.1  57.1  57.1  57.1
#
#    2014  2015  2016  2017  2018  2019  2020
# 0  11.4  11.4  11.4  11.4  11.4   6.4   6.4
# 1  32.1  32.1  32.1  28.6  28.6  28.6  28.6
# 2  40.0  43.6  43.6  47.1  47.1  53.6  53.6
# 3  35.7  35.7  35.7  35.7  39.3  39.3  39.3
# 4  57.1  50.0  50.0  50.0  53.6  53.6  53.6

# %%
happy = pd.read_csv('./happiness_score_whr.csv')

# %%
happy.head()
# Out:
#                 country  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# 0           Afghanistan   NaN   NaN   NaN  37.2  44.0  47.6  38.3  37.8  35.7
# 1                Angola   NaN   NaN   NaN   NaN   NaN   NaN  55.9  43.6  39.4
# 2               Albania   NaN   NaN  46.3   NaN  54.9  52.7  58.7  55.1  45.5
# 3  United Arab Emirates   NaN  67.3   NaN   NaN  68.7  71.0  71.2  72.2  66.2
# 4             Argentina   NaN  63.1  60.7  59.6  64.2  64.4  67.8  64.7  65.8
#
#    2014  2015  2016  2017  2018  2019
# 0  31.3  39.8  42.2  26.6  26.9  25.7
# 1  37.9   NaN   NaN   NaN   NaN   NaN
# 2  48.1  46.1  45.1  46.4  50.0  48.8
# 3  65.4  65.7  68.3  70.4  66.0  67.9
# 4  66.7  67.0  64.3  60.4  57.9  59.7

# %%
pop = pd.read_csv('./population_WB.csv')

# %%
pop
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54208.0      55434.0
# 1    Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                    Afghanistan          AFG    8996967.0    9169406.0
# 3     Africa Western and Central          AFW   96396419.0   98407221.0
# 4                         Angola          AGO    5454938.0    5531451.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5315351.0    5393034.0
# 263                 South Africa          ZAF   17099836.0   17524533.0
# 264                       Zambia          ZMB    3070780.0    3164330.0
# 265                     Zimbabwe          ZWE    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
wom = pd.read_csv('./women_in_parliament.csv')

# %%
wom.head()
# Out:
#                 country  1945  1946  1947  1948  1949  1950  1951  1952  1953  \
# 0           Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1                Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2               Albania  3.66  6.46  8.81  10.8  12.5  14.1  13.5  12.9  12.4
# 3               Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  ...  27.4  27.4  27.4  27.4  27.4  27.7  27.8  27.9  27.2  27.2
# 1  ...  34.9  34.1  33.5  32.8  32.2  31.6  30.9  30.4  30.0  30.0
# 2  ...  16.1  15.9  15.7  18.8  21.8  24.8  27.9  28.6  29.5  29.5
# 3  ...  51.8  50.0  47.6  44.3  39.3  41.1  42.9  44.6  46.4  46.4
# 4  ...   5.0  17.5  19.2  20.8  22.5  29.4  36.3  43.1  50.0  50.0
#
# [5 rows x 77 columns]

# %%
inc = pd.read_csv('./average_daily_income.csv', sep=';')

# %%
inc.head()
# Out:
#                 country    1800    1801    1802    1803    1804    1805  \
# 0           Afghanistan  919.00  919.00  919.00  919.00  919.00  919.00
# 1                Angola    2.27    2.27    2.28    2.29    2.30    2.31
# 2               Albania    1.22    1.22    1.22    1.22    1.22    1.22
# 3               Andorra    1.48    1.49    1.49    1.49    1.49    1.50
# 4  United Arab Emirates    2.90    2.91    2.92    2.93    2.94    2.95
#
#      1806    1807    1808  ...   2012   2013   2014   2015   2016   2017  \
# 0  919.00  919.00  919.00  ...   2.83   2.89   2.87   2.82   2.81   2.81
# 1    2.32    2.33    2.35  ...   3.73   3.76   3.78   3.67   3.55   3.37
# 2    1.22    1.22    1.22  ...   7.99   8.20   8.52   8.62   8.79   8.73
# 3    1.50    1.50    1.51  ...  52.00  54.20  55.70  57.70  59.70  61.70
# 4    2.96    2.97    2.98  ...  70.40  73.60  83.70  69.10  71.20  78.70
#
#     2018   2019   2020   2021
# 0   2.77   2.82   2.62   2.66
# 1   3.12   2.99   2.79   2.72
# ...

# %%
conts = pd.read_csv('./continents.csv', sep=';')

# %%
conts.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
inc_ine = pd.read_csv('./income-inequality.csv', sep=';')

# %%
inc_ine.head()
# Out:
#                 country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0           Afghanistan  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5  30.5
# 1                Angola  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7
# 2               Albania  39.9  39.9  39.9  39.9  39.9  39.9  39.9  39.9  39.9
# 3               Andorra  42.5  42.5  42.5  42.5  42.5  42.5  42.5  42.5  42.5
# 4  United Arab Emirates  39.8  39.8  39.8  39.8  39.8  39.8  39.8  39.7  39.7
#
#    ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  ...  37.7  37.7  37.7  37.7  37.7  37.7  37.7  37.7  38.3  39.0
# 1  ...  46.0  46.8  47.7  48.5  49.4  50.3  51.3  51.3  52.1  53.0
# 2  ...  29.0  31.6  34.6  32.9  33.7  33.2  33.2  33.2  33.8  34.5
# 3  ...  35.5  35.4  35.4  35.3  35.2  35.2  35.1  35.0  35.0  35.0
# 4  ...  32.6  32.5  31.1  29.7  28.4  27.2  26.0  26.0  26.0  26.7
#
# [5 rows x 223 columns]

# %% [markdown]
# ###How is the distribution of the Happiness score across: countries? continents?

# %%
null_counts = inc_ine.isnull().sum()
null_counts
# Out:
# country    0
# 1800       0
# 1801       0
# 1802       0
# 1803       0
#           ..
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# Length: 223, dtype: int64

# %%
merged_df = pd.merge(conts, inc_ine, on='country')

# %%
merged_df
# Out:
#          continent    country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0           Africa    Algeria  56.2  56.2  56.2  56.2  56.2  56.2  56.2  56.2
# 1           Africa     Angola  57.7  57.7  57.7  57.7  57.7  57.7  57.7  57.7
# 2           Africa      Benin  40.1  40.1  40.1  40.1  40.1  40.1  40.1  40.1
# 3           Africa   Botswana  46.5  46.5  46.5  46.5  46.5  46.5  46.5  46.5
# 4           Africa    Burundi  34.3  34.3  34.3  34.3  34.3  34.3  34.3  34.3
# ..             ...        ...   ...   ...   ...   ...   ...   ...   ...   ...
# 170  South America   Paraguay  40.8  40.8  40.8  40.8  40.8  40.8  40.8  40.8
# 171  South America       Peru  53.1  53.1  53.1  53.1  53.1  53.1  53.1  53.1
# 172  South America   Suriname  45.8  45.8  45.8  45.8  45.8  45.8  45.8  45.8
# 173  South America    Uruguay  49.1  49.1  49.1  49.1  49.1  49.1  49.1  49.1
# 174  South America  Venezuela  60.4  60.4  60.4  60.4  60.4  60.4  60.4  60.4
#
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
melted_df = pd.melt(merged_df, id_vars=['country', 'continent'], var_name='year', value_name='income')

# %%
melted_df['year'] = pd.to_numeric(melted_df['year'])

# %%
melted_df = melted_df.sort_values(by='year')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(melted_df['year'], melted_df['income'], s=20, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Income')
plt.title('Income over the Years')
plt.grid(True)
plt.show()

# %%
merged_df2 = pd.merge(conts, happy, on='country')
merged_df2
# Out:
#          continent    country  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0           Africa    Algeria   NaN   NaN   NaN   NaN   NaN  54.6  53.2  56.0
# 1           Africa     Angola   NaN   NaN   NaN   NaN   NaN   NaN  55.9  43.6
# 2           Africa      Benin   NaN  33.3   NaN  36.7   NaN   NaN  38.7  31.9
# 3           Africa   Botswana   NaN  47.4   NaN  54.5   NaN  35.5  35.2  48.4
# 4           Africa    Burundi   NaN   NaN   NaN  35.6  37.9   NaN  37.1   NaN
# ..             ...        ...   ...   ...   ...   ...   ...   ...   ...   ...
# 143  South America   Paraguay   NaN  47.3  52.7  55.7  55.8  58.4  56.8  58.2
# 144  South America       Peru   NaN  48.1  52.1  51.3  55.2  56.1  58.9  58.2
# 145  South America   Suriname   NaN   NaN   NaN   NaN   NaN   NaN   NaN  62.7
# 146  South America    Uruguay   NaN  57.9  56.9  56.6  63.0  60.6  65.5  64.5
# 147  South America  Venezuela  71.7  65.3   NaN  62.6  71.9  74.8  65.8  70.7
#
# ...

# %%
melted_df2 = pd.melt(merged_df2, id_vars=['country', 'continent'], var_name='year', value_name='happiness')

# %%
melted_df2['year'] = pd.to_numeric(melted_df['year'])

# %%
melted_df2 = melted_df.sort_values(by='year')

# %%
melted_df2
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
melted_df2.isnull()
# Out:
#       country  continent   year  happiness
# 0       False      False  False       True
# 73      False      False  False      False
# 2       False      False  False       True
# 3       False      False  False       True
# 4       False      False  False       True
# ...       ...        ...    ...        ...
# 2215    False      False  False      False
# 2216    False      False  False      False
# 2146    False      False  False      False
# 2182    False      False  False      False
# 2219    False      False  False      False
#
# [2220 rows x 4 columns]

# %%
null_counts = melted_df2.isnull().sum()

# %%
null_counts
# Out:
# country        0
# continent      0
# year           0
# happiness    543
# dtype: int64

# %%
sns.set_style('whitegrid')
color_palette = sns.color_palette('Set2')
plt.figure(figsize=(10,5))

sns.scatterplot(data=melted_df2, x= 'year', y = 'happiness', 
                #size = 'population_in_thousands', 
                hue='continent')

#countries_to_annotate = ['Yemen', 'Rwanda', 'Vanuatu', 'Ecuador', 'Moldova']
#for country in countries_to_annotate:
    #df_country=df_subset[df_subset['country']== country]
    #plt.annotate (xy=(df_country.iloc[0]['life_expectancy'] , df_country.iloc[0]['fertility']),text=country )

plt.title('Happines')
plt.xlabel('years')
plt.ylabel('happiness')
plt.grid(True)
plt.axis([10, 85, 0, 9.5])
plt.xticks(rotation=45)
plt.legend(title='Continents', title_fontsize=8, shadow=True, fontsize=8, loc = 3)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=melted_df2, x='year', y='happiness', hue='continent', palette='Set1', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years')
plt.grid(True)
plt.legend(title='Continent')
plt.show()

# %%
asia_df = melted_df2[melted_df2['continent'] == 'Asia']

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=asia_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years in Asia')
plt.grid(True)
plt.show()

# %%
algeria_df = melted_df2[melted_df2['country'] == 'Algeria']

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=algeria_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years in Algeria')
plt.grid(True)
plt.show()

# %%
import imageio
import os

# %%
unique_countries = merged_df2['country'].unique()
unique_countries
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burundi', 'Cameroon',
#        'Central African Republic', 'Chad', 'Comoros', 'Djibouti', 'Egypt',
#        'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', 'Kenya',
#        'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia',
#        'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somalia',
#        'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo',
#        'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe', 'Afghanistan',
#        'Bahrain', 'Bangladesh', 'Bhutan', 'Cambodia', 'China', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kuwait', 'Lebanon', 'Malaysia', 'Maldives',
#        'Mongolia', 'Nepal', 'Oman', 'Pakistan', 'Philippines', 'Qatar',
#        'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syria', 'Tajikistan',
# ...

# %%
path =('../images')
os.makedirs(path, exist_ok=True)

for country in unique_countries:
    country_df = merged_df2[merged_df2['country'] == country]

    sns.set_style('whitegrid')
    color_palette = sns.color_palette('Set2')
    plt.figure(figsize=(10, 5))

    images = []

    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title(f'Happiness over the Years in {country}')
    plt.grid(True)
    plt.show()
    
    filename = os.path.join(path, f'plot_{country}.png')
    plt.savefig(filename)
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 14
#      11 images = []
#      13 plt.figure(figsize=(10, 6))
# ---> 14 sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
#      15 plt.xlabel('Year')
#      16 plt.ylabel('Happiness')
#
# File ~\miniconda3\lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
melted_df2['year'] = pd.to_numeric(melted_df2['year'])

# %%
unique_countries = melted_df2['country'].unique()

# %%
for country in unique_countries:
    # Filter the DataFrame for the current country
    country_df = melted_df2[melted_df2['country'] == country]

# %%
plt.figure(figsize=(10, 6))
    sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title(f'Happiness over the Years in {country}')
    plt.grid(True)
    plt.show()
# Out:
#   Cell In[100], line 2
#     sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
#     ^
# IndentationError: unexpected indent

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=algeria_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years in Algeria')
plt.grid(True)
plt.show()

# %%
country_df
# Out:
#       country      continent  year  happiness
# 141   Ecuador  South America  2005        NaN
# 289   Ecuador  South America  2006       50.2
# 437   Ecuador  South America  2007       50.0
# 585   Ecuador  South America  2008       53.0
# 733   Ecuador  South America  2009       60.2
# 881   Ecuador  South America  2010       58.4
# 1029  Ecuador  South America  2011       58.0
# 1177  Ecuador  South America  2012       59.6
# 1325  Ecuador  South America  2013       60.2
# 1473  Ecuador  South America  2014       59.5
# 1621  Ecuador  South America  2015       59.6
# 1769  Ecuador  South America  2016       61.2
# 1917  Ecuador  South America  2017       58.4
# 2065  Ecuador  South America  2018       61.3
# 2213  Ecuador  South America  2019       59.3

# %%
melted_df2
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
Africa_df = melted_df2[melted_df2['continent'] == 'Africa']

# %%
Africa_df
# Out:
#            country continent  year  happiness
# 0          Algeria    Africa  2005        NaN
# 2            Benin    Africa  2005        NaN
# 3         Botswana    Africa  2005        NaN
# 4          Burundi    Africa  2005        NaN
# 5         Cameroon    Africa  2005        NaN
# ...            ...       ...   ...        ...
# 2112        Uganda    Africa  2019       44.3
# 2113        Zambia    Africa  2019       37.6
# 2114      Zimbabwe    Africa  2019       33.0
# 2106  South Africa    Africa  2019       48.1
# 2109      Tanzania    Africa  2019       34.8
#
# [645 rows x 4 columns]

# %%
df_2011 = Africa_df[Africa_df['year'] == 2011]
df_2011
# Out:
#                       country continent  year  happiness
# 892                   Burundi    Africa  2011       37.1
# 888                   Algeria    Africa  2011       53.2
# 889                    Angola    Africa  2011       55.9
# 890                     Benin    Africa  2011       38.7
# 891                  Botswana    Africa  2011       35.2
# 893                  Cameroon    Africa  2011       44.3
# 901                    Gambia    Africa  2011        NaN
# 895                      Chad    Africa  2011       43.9
# 896                   Comoros    Africa  2011       38.4
# 897                  Djibouti    Africa  2011       43.7
# 898                     Egypt    Africa  2011       41.7
# 899                  Ethiopia    Africa  2011        NaN
# 900                     Gabon    Africa  2011       42.6
# 894  Central African Republic    Africa  2011       36.8
# 902                     Ghana    Africa  2011       56.1
# ...

# %%
year_2005_df = Africa_df[Africa_df['year'] == 2005]
year_2005_df.head()
# Out:
#     country continent  year  happiness
# 0   Algeria    Africa  2005        NaN
# 2     Benin    Africa  2005        NaN
# 3  Botswana    Africa  2005        NaN
# 4   Burundi    Africa  2005        NaN
# 5  Cameroon    Africa  2005        NaN

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=year_2005_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness in Africa (2005-2019)')
plt.grid(True)

# Set the tick positions on the X-axis to show only the years from 2005 till 2019
plt.xticks(ticks=range(2005, 2020), rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=year_2005_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years in Algeria')
plt.grid(True)
plt.ylim(25, 85)
scatter.set_xlim(left=2004, right=2020)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[173], line 8
#       6 plt.grid(True)
#       7 plt.ylim(25, 85)
# ----> 8 scatter.set_xlim(left=2004, right=2020)
#      10 plt.show()
#
# NameError: name 'scatter' is not defined

# %%
happy.max()
# Out:
# country    Zimbabwe
# 2005           80.2
# 2006           76.7
# 2007           78.3
# 2008           79.7
# 2009           76.8
# 2010           77.7
# 2011           77.9
# 2012           77.8
# 2013           75.9
# 2014           75.1
# 2015           76.0
# 2016           76.6
# 2017           77.9
# 2018           78.6
# 2019           78.1
# dtype: object

# %%
max_happiness = df['happiness'].max()

# %%
path =('../images')
os.makedirs(path, exist_ok=True)

for country in unique_countries:
    country_df = Africa_df[Africa_df['country'] == country]
    
    plt.figure(figsize=(10, 6))
    
    images = []

    sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title(f'Level of Happiness over the Years')
    plt.grid(True)
    plt.ylim(25, 85)
    
    # Set the tick positions on the X-axis using unique_years
    unique_years = sorted(country_df['year'].unique())
    plt.xticks(ticks=unique_years, rotation=45)
    
    sns.scatterplot(data=df_temp, x='life_expectancy', y='fertility',
                    size='population_in_thousands', hue='continent', alpha=0.7, sizes=(30, 200))

    countries_to_annotate = df_temp[df_temp['country'].isin(['Yemen', 'Rwanda', 'Vanuatu', 'Ecuador', 'Moldova'])]
    for _, row in countries_to_annotate.iterrows():
        plt.annotate(xy=(row['life_expectancy'], row['fertility']), text=row['country'])
    
    plt.title(f'Fertility vs Life Expectancy in {year}')
    plt.xlabel('life_expectancy')
    plt.ylabel('fertility')
    plt.grid(True)
    plt.axis([10, 85, 0, 9.5])
    plt.xticks(rotation=45)
    plt.legend(title='Continents', title_fontsize=7, shadow=True, fontsize=7, loc = 3)
    
    filename = os.path.join(path, f'plot_{year}.png')
    plt.savefig(filename)
    plt.close()

# %%
unique_countries = Africa_df['country'].unique()

# %%
for country in unique_countries:
    # Filter the DataFrame for the current country
    country_df = Africa_df[Africa_df['country'] == country]

# %%
plt.figure(figsize=(10, 6))
    sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title(f'Level of Happiness over the Years in {country}')
    plt.grid(True)
    plt.ylim(25, 85)
    
    # Set the tick positions on the X-axis using unique_years
    unique_years = sorted(country_df['year'].unique())
    plt.xticks(ticks=unique_years, rotation=45)
    
    # Save the scatter plot as an image
    plt.savefig(f'{country}_scatterplot.png')
    
    # Close the current figure to avoid overlapping plots
    plt.close()
# Out:
#   Cell In[133], line 2
#     sns.scatterplot(data=country_df, x='year', y='happiness', s=100, alpha=0.7)
#     ^
# IndentationError: unexpected indent

# %%
country_df
# Out:
#       country continent  year  happiness
# 17    Lesotho    Africa  2005        NaN
# 165   Lesotho    Africa  2006        NaN
# 313   Lesotho    Africa  2007        NaN
# 461   Lesotho    Africa  2008        NaN
# 609   Lesotho    Africa  2009        NaN
# 757   Lesotho    Africa  2010        NaN
# 905   Lesotho    Africa  2011       49.0
# 1053  Lesotho    Africa  2012        NaN
# 1201  Lesotho    Africa  2013        NaN
# 1349  Lesotho    Africa  2014        NaN
# 1497  Lesotho    Africa  2015        NaN
# 1645  Lesotho    Africa  2016       38.1
# 1793  Lesotho    Africa  2017       38.0
# 1941  Lesotho    Africa  2018        NaN
# 2089  Lesotho    Africa  2019       36.5

# %%
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=year_2005_df, x='year', y='happiness', s=100, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Happiness over the Years in Algeria')
plt.grid(True)

# Set the X-axis limits from 2004 to 2020
scatter.set_xlim(left=2004, right=2020)

# Set the Y-axis limits
plt.ylim(25, 85)

plt.show()

# %%
year_2005_df
# Out:
#                      country continent  year  happiness
# 0                    Algeria    Africa  2005        NaN
# 2                      Benin    Africa  2005        NaN
# 3                   Botswana    Africa  2005        NaN
# 4                    Burundi    Africa  2005        NaN
# 5                   Cameroon    Africa  2005        NaN
# 6   Central African Republic    Africa  2005        NaN
# 16                     Kenya    Africa  2005        NaN
# 7                       Chad    Africa  2005        NaN
# 9                   Djibouti    Africa  2005        NaN
# 10                     Egypt    Africa  2005       51.7
# 11                  Ethiopia    Africa  2005        NaN
# 12                     Gabon    Africa  2005        NaN
# 13                    Gambia    Africa  2005        NaN
# 14                     Ghana    Africa  2005        NaN
# 8                    Comoros    Africa  2005        NaN
# 18                   Liberia    Africa  2005        NaN
# ...

# %%
year_2019_df = Africa_df[Africa_df['year'] == 2019]
year_2019_df.head()
# Out:
#        country continent  year  happiness
# 2072   Algeria    Africa  2019       50.1
# 2073    Angola    Africa  2019        NaN
# 2074     Benin    Africa  2019       52.2
# 2075  Botswana    Africa  2019       34.8
# 2076   Burundi    Africa  2019       37.8

# %%
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=year_2019_df, x='year', y='happiness', s=40, alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Level of Happiness over the Years')
plt.grid(True)

# Set the X-axis limits from 2004 to 2020
scatter.set_xlim(left=2004, right=2020)

# Set the Y-axis limits
plt.ylim(25, 85)

plt.show()

# %%
years_range_df = Africa_df[(Africa_df['year'] >= 2004) & (Africa_df['year'] <= 2020)]

# %%
path =('../images')
os.makedirs(path, exist_ok=True)

for year in range(2005, 2020):
   
    year_df = years_range_df[years_range_df['year'] == year]
    
    images = []
    
   
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=year_df, x='year', y='happiness', s=50, alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title(f'Happiness over the Years')
    plt.grid(True)
    
    # Set the X-axis and Y-axis limits
    plt.xlim(2004, 2020)
    plt.ylim(25, 85)

    filename = os.path.join(path, f'plot_{year}.png')
    plt.savefig(filename)
    plt.close()

# %%
hap_by_con
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
hap_by_con = melted_df.sort_values(by='year')

# %%
df_2005 = hap_by_con[hap_by_con['year'] == 2005]
df_2005.head()
# Out:
#      country continent  year  happiness
# 0    Algeria    Africa  2005        NaN
# 73    Turkey      Asia  2005       47.2
# 2      Benin    Africa  2005        NaN
# 3   Botswana    Africa  2005        NaN
# 4    Burundi    Africa  2005        NaN

# %%
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=df_2005, x='year', y='happiness', s=40, hue= 'continent', alpha=0.7)
plt.xlabel('Year')
plt.ylabel('Happiness')
plt.title('Level of Happiness over the Years')
plt.grid(True)

scatter.set_xlim(left=2004, right=2020)
plt.ylim(25, 85)
plt.legend(loc='lower left', bbox_to_anchor=(0.0, 1.01), title='Continent', fontsize='small')
plt.xticks(ticks=range(2004, 2020), rotation=45)
for index, row in filtered_df.iterrows():
    plt.text(row['year'], row['happiness'], row['country'], ha='left', va='bottom', fontsize=8)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 scatter = sns.scatterplot(data=df_2005, x='year', y='happiness', s=40, hue= 'continent', alpha=0.7)
#       3 plt.xlabel('Year')
#       4 plt.ylabel('Happiness')
#
# NameError: name 'df_2005' is not defined

# %%
path =('../images')
os.makedirs(path, exist_ok=True)

for year in range(2005, 2020):
   
    year_df = years_range_df[years_range_df['year'] == year]
    
    images = []
    
   
    plt.figure(figsize=(10, 6))
    scatter = sns.scatterplot(data=year_df, x='year', y='happiness', s=40, hue= 'continent', alpha=0.7)
    plt.xlabel('Year')
    plt.ylabel('Happiness')
    plt.title('Level of Happiness over the Years')
    plt.grid(True)

    scatter.set_xlim(left=2004, right=2020)
    plt.ylim(25, 85)
    plt.legend(loc='lower left', bbox_to_anchor=(0.0, 1.01), title='Continent', fontsize='small')
    plt.xticks(ticks=range(2004, 2020), rotation=45)

    filename = os.path.join(path, f'plot_{year}.png')
    plt.savefig(filename)
    plt.close()

# %%
years_range_df = hap_by_con[(hap_by_con['year'] >= 2004) & (hap_by_con['year'] <= 2020)]

# %%
years_range_df
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
# Out:
# (25.0, 85.0)

# %%
df_2005
# Out:
#        country      continent  year  happiness
# 0      Algeria         Africa  2005        NaN
# 73      Turkey           Asia  2005       47.2
# 2        Benin         Africa  2005        NaN
# 3     Botswana         Africa  2005        NaN
# 4      Burundi         Africa  2005        NaN
# ..         ...            ...   ...        ...
# 144       Peru  South America  2005        NaN
# 145   Suriname  South America  2005        NaN
# 146    Uruguay  South America  2005        NaN
# 147  Venezuela  South America  2005       71.7
# 141    Ecuador  South America  2005        NaN
#
# [148 rows x 4 columns]

# %%
df_2005_Af = df_2005[df_2005['continent'] == 'Africa']
df_2005_Af.describe()
# Out:
#          year  happiness
# count    43.0        1.0
# mean   2005.0       51.7
# std       0.0        NaN
# min    2005.0       51.7
# 25%    2005.0       51.7
# 50%    2005.0       51.7
# 75%    2005.0       51.7
# max    2005.0       51.7

# %%
hap_by_con
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
df_2006_Af = hap_by_con[(hap_by_con['year'] == 2006) & (hap_by_con['continent'] == 'Africa')]

# %%
df_2006_Af.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_2006_Af.describe()
#
# NameError: name 'df_2006_Af' is not defined

# %%
min_happiness_country = df_2006_Af.loc[df_2006_Af['happiness'].idxmin(), 'country']
min_happiness_country
# Out:
# 'Togo'

# %%
max_happiness_country = df_2006_Af.loc[df_2006_Af['happiness'].idxmax(), 'country']
max_happiness_country
# Out:
# 'South Africa'

# %%
filtered_countries = df_2006_Af[(df_2006_Af['happiness'] >= 38) & (df_2006_Af['happiness'] <= 42)]
filtered_countries
# Out:
#         country continent  year  happiness
# 153    Cameroon    Africa  2006       38.5
# 168  Madagascar    Africa  2006       39.8
# 169      Malawi    Africa  2006       38.3
# 170        Mali    Africa  2006       40.1
# 190    Zimbabwe    Africa  2006       38.3
# 185    Tanzania    Africa  2006       39.2

# %%
df_2006_eg = hap_by_con[(hap_by_con['year'] == 2007) & (hap_by_con['country'] == 'Egypt')]
df_2006_eg
# Out:
#     country continent  year  happiness
# 306   Egypt    Africa  2007       55.4

# %%
hap_by_con.to_csv('Happiness_level_by_year.csv')

# %%
max_happiness_country = hap_by_con.loc[hap_by_con['happiness'].idxmax(), 'continent']
max_happiness_country
# Out:
# 'Europe'

# %%
hap_by_con
# Out:
#            country      continent  year  happiness
# 0          Algeria         Africa  2005        NaN
# 73          Turkey           Asia  2005       47.2
# 2            Benin         Africa  2005        NaN
# 3         Botswana         Africa  2005        NaN
# 4          Burundi         Africa  2005        NaN
# ...            ...            ...   ...        ...
# 2215      Paraguay  South America  2019       56.9
# 2216          Peru  South America  2019       58.0
# 2146  Turkmenistan           Asia  2019       51.2
# 2182      Portugal         Europe  2019       59.1
# 2219     Venezuela  South America  2019       50.5
#
# [2220 rows x 4 columns]

# %%
continent_avg_happiness = hap_by_con.groupby('continent')['happiness'].mean()

# %%
min_avg_happiness_continent = continent_avg_happiness.idxmin()

# %%
print("Continent with Minimal Average Happiness:", min_avg_happiness_continent)
# Out:
# Continent with Minimal Average Happiness: Africa

# %%
africa_df = hap_by_con[hap_by_con['continent'] == 'Africa']

# %%
avg_happiness_africa = africa_df['happiness'].mean()

# %%
print("Average Happiness in Africa:", avg_happiness_africa)
# Out:
# Average Happiness in Africa: 43.465795724465565
