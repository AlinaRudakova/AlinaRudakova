# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./all_data_merged.csv')
df
# Out:
#        Unnamed: 0        country continent  year  happiness  democracy_score  \
# 0               0        Algeria    Africa  2005        NaN              NaN
# 1               1         Turkey      Asia  2005       47.2              NaN
# 2               2          Benin    Africa  2005        NaN              NaN
# 3               3       Botswana    Africa  2005        NaN              NaN
# 4               4        Burundi    Africa  2005        NaN              NaN
# ...           ...            ...       ...   ...        ...              ...
# 48975       48975       Holy See       NaN  2018        NaN              NaN
# 48976       48976       Holy See       NaN  2019        NaN              NaN
# 48977       48977       Holy See       NaN  2020        NaN              NaN
# 48978       48978       Holy See       NaN  2021        NaN              NaN
# 48979       48979  Liechtenstein       NaN  2021        NaN              NaN
#
# ...

# %%
df['country'].unique()
# Out:
# array(['Algeria', 'Turkey', 'Benin', 'Botswana', 'Burundi', 'Cameroon',
#        'Central African Republic', 'Kenya', 'Chad', 'Djibouti', 'Egypt',
#        'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Comoros', 'Liberia',
#        'South Sudan', 'Libya', 'Madagascar', 'Malawi', 'Mali',
#        'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia',
#        'Niger', 'Nigeria', 'Rwanda', 'Senegal', 'Sierra Leone', 'Somalia',
#        'South Africa', 'Guinea', 'Sudan', 'Angola', 'Nepal', 'Tunisia',
#        'Uganda', 'Zambia', 'Zimbabwe', 'Japan', 'Bahrain', 'Bangladesh',
#        'Afghanistan', 'Cambodia', 'China', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Bhutan', 'Togo', 'Thailand', 'Israel', 'Jordan',
#        'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Tanzania', 'Oman',
#        'Kazakhstan', 'Pakistan', 'Qatar', 'Saudi Arabia', 'Singapore',
#        'Sri Lanka', 'Syria', 'Tajikistan', 'Philippines', 'Kuwait',
# ...

# %%
top_countries = ['Denmark','Finland','Burundi','Central African Republic','Comoros','South Sudan', 'Rwanda',
       'Afghanistan', 'Togo', 'Tanzania', 'Iceland', 'Netherlands', 'Norway',
       'Switzerland', 'Canada','Haiti', 'Australia',
       'New Zealand', 'Sweden', 'Yemen']

# %%
arabian_peninsula = ['United Arab Emirates', 'Oman', 'Qatar', 'Saudi Arabia', 'Bahrain', 'Kuwait', 'Yemen']

# %%
filtered_df_top = df[df['country'].isin(top_countries)]
filtered_df_top
# Out:
#        Unnamed: 0                   country continent  year  happiness  \
# 4               4                   Burundi    Africa  2005        NaN
# 6               6  Central African Republic    Africa  2005        NaN
# 15             15                   Comoros    Africa  2005        NaN
# 17             17               South Sudan    Africa  2005        NaN
# 29             29                    Rwanda    Africa  2005        NaN
# ...           ...                       ...       ...   ...        ...
# 48576       48576               South Sudan       NaN  2021        NaN
# 48581       48581                    Sweden       NaN  2021        NaN
# 48586       48586                      Togo       NaN  2021        NaN
# 48597       48597                  Tanzania       NaN  2021        NaN
# 48608       48608                     Yemen       NaN  2021        NaN
#
#        democracy_score  index_of_functioning_goverment code  population  \
# ...

# %%
filtered_df_top.to_csv('top_countries.csv')

# %%
filtered_df_arab = df[df['country'].isin(arabian_peninsula)]
filtered_df_arab
# Out:
#        Unnamed: 0       country continent  year  happiness  democracy_score  \
# 43             43       Bahrain      Asia  2005        NaN              NaN
# 62             62          Oman      Asia  2005        NaN              NaN
# 65             65         Qatar      Asia  2005        NaN              NaN
# 66             66  Saudi Arabia      Asia  2005       70.8              NaN
# 72             72        Kuwait      Asia  2005        NaN              NaN
# ...           ...           ...       ...   ...        ...              ...
# 48512       48512        Kuwait       NaN  2021        NaN              NaN
# 48550       48550          Oman       NaN  2021        NaN              NaN
# 48562       48562         Qatar       NaN  2021        NaN              NaN
# 48566       48566  Saudi Arabia       NaN  2021        NaN              NaN
# 48608       48608         Yemen       NaN  2021        NaN              NaN
#
# ...

# %%
filtered_df_arab.to_csv('arab_countries_clean.csv')

# %%
filtered_df_arab.isnull().sum()
# Out:
# Unnamed: 0                           0
# country                              0
# continent                         1449
# year                                 0
# happiness                         1489
# democracy_score                   1449
# index_of_functioning_goverment    1449
# code                              1188
# population                        1191
# women_in_parliament_%             1362
# daily_income_usd                     0
# income_inequlity                     0
# dtype: int64

# %%
filtered_df_arab = df.dropna()
filtered_df_arab
# Out:
#       Unnamed: 0       country      continent  year  happiness  \
# 150          150         Benin         Africa  2006       33.3
# 151          151      Botswana         Africa  2006       47.4
# 153          153      Cameroon         Africa  2006       38.5
# 155          155    Madagascar         Africa  2006       39.8
# 161          161         Ghana         Africa  2006       45.4
# ...          ...           ...            ...   ...        ...
# 2213        2213       Ecuador  South America  2019       59.3
# 2215        2215      Paraguay  South America  2019       56.9
# 2216        2216          Peru  South America  2019       58.0
# 2217        2217  Turkmenistan           Asia  2019       51.2
# 2218        2218      Portugal         Europe  2019       59.1
#
#       democracy_score  index_of_functioning_goverment code  population  \
# 150              61.6                            64.3  BEN   8216893.0
# ...

# %%
# Out:
#       Unnamed: 0       country      continent  year  happiness  \
# 150          150         Benin         Africa  2006       33.3
# 151          151      Botswana         Africa  2006       47.4
# 153          153      Cameroon         Africa  2006       38.5
# 155          155    Madagascar         Africa  2006       39.8
# 161          161         Ghana         Africa  2006       45.4
# ...          ...           ...            ...   ...        ...
# 2213        2213       Ecuador  South America  2019       59.3
# 2215        2215      Paraguay  South America  2019       56.9
# 2216        2216          Peru  South America  2019       58.0
# 2217        2217  Turkmenistan           Asia  2019       51.2
# 2218        2218      Portugal         Europe  2019       59.1
#
#       democracy_score  index_of_functioning_goverment code  population  \
# 150              61.6                            64.3  BEN   8216893.0
# ...

# %%
dfarab_clean.to_csv('arab_clean_data.csv')

# %%
dfAf = df[df['continent'] == 'Africa']
dfAf

# %%
dfAf['country'].unique()

# %%
dfAf['country'].nunique()

# %%
dfarab = pd.read_csv('./arab_countries.csv')
dfarab
# Out:
#       Unnamed: 0.1  Unnamed: 0       country continent  year  happiness  \
# 0               43          43       Bahrain      Asia  2005        NaN
# 1               62          62          Oman      Asia  2005        NaN
# 2               65          65         Qatar      Asia  2005        NaN
# 3               66          66  Saudi Arabia      Asia  2005       70.8
# 4               72          72        Kuwait      Asia  2005        NaN
# ...            ...         ...           ...       ...   ...        ...
# 1549         48512       48512        Kuwait       NaN  2021        NaN
# 1550         48550       48550          Oman       NaN  2021        NaN
# 1551         48562       48562         Qatar       NaN  2021        NaN
# 1552         48566       48566  Saudi Arabia       NaN  2021        NaN
# 1553         48608       48608         Yemen       NaN  2021        NaN
#
#       democracy_score  index_of_functioning_goverment code  population  \
# ...

# %%
dfarab_clean = dfarab.dropna()
dfarab_clean
# Out:
#      Unnamed: 0.1  Unnamed: 0               country continent  year  \
# 7             185         185                Kuwait      Asia  2006
# 13            248         248  United Arab Emirates      Asia  2006
# 18            363         363          Saudi Arabia      Asia  2007
# 25            509         509          Saudi Arabia      Asia  2008
# 28            629         629                Kuwait      Asia  2009
# 31            657         657                 Qatar      Asia  2009
# 32            658         658          Saudi Arabia      Asia  2009
# 34            720         720  United Arab Emirates      Asia  2009
# 36            798         798                Kuwait      Asia  2010
# 38            806         806                 Qatar      Asia  2010
# 39            807         807          Saudi Arabia      Asia  2010
# 40            816         816  United Arab Emirates      Asia  2010
# 43            944         944                Kuwait      Asia  2011
# ...
