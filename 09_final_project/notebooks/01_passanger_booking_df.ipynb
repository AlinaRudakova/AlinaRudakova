# %%
import pandas as pd

# %%
df = pd.read_csv('../data/01_passanger_booking_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50002 entries, 0 to 50001
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50002 non-null  int64
#  1   sales_channel          50002 non-null  object
#  2   trip_type              50002 non-null  object
#  3   purchase_lead          50002 non-null  int64
#  4   length_of_stay         50002 non-null  int64
#  5   flight_hour            50002 non-null  int64
#  6   flight_day             50002 non-null  object
#  7   route                  50002 non-null  object
#  8   booking_origin         50002 non-null  object
#  9   wants_extra_baggage    50002 non-null  int64
#  10  wants_preferred_seat   50002 non-null  int64
#  11  wants_in_flight_meals  50002 non-null  int64
#  12  flight_duration        50002 non-null  float64
#  13  booking_complete       50002 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            6        Tue  AKLHGH      Australia                    0
# 1            7        Sat  AKLDEL    New Zealand                    1
# 2            3        Sat  AKLDEL    New Zealand                    0
# 3           17        Wed  AKLDEL          India                    1
# 4            4        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
df.isnull().sum()
# Out:
# num_passengers           0
# sales_channel            0
# trip_type                0
# purchase_lead            0
# length_of_stay           0
# flight_hour              0
# flight_day               0
# route                    0
# booking_origin           0
# wants_extra_baggage      0
# wants_preferred_seat     0
# wants_in_flight_meals    0
# flight_duration          0
# booking_complete         0
# dtype: int64

# %% [markdown]
# ### Assigning continent

# %%
unique_booking_origins = df['booking_origin'].unique()

# %%
unique_booking_origins
# Out:
# array(['Australia', 'New Zealand', 'India', 'United Kingdom', 'China',
#        'South Korea', 'Canada', 'Japan', 'Malaysia', 'Singapore',
#        'Switzerland', 'Germany', 'Indonesia', 'Czech Republic', 'Vietnam',
#        'Thailand', 'Spain', 'Romania', 'Ireland', 'Italy', 'Slovakia',
#        'United Arab Emirates', 'Tonga', 'Réunion', '(not set)',
#        'Saudi Arabia', 'Netherlands', 'Qatar', 'Hong Kong', 'Philippines',
#        'Sri Lanka', 'France', 'Croatia', 'United States', 'Laos',
#        'Hungary', 'Portugal', 'Cyprus', 'Cambodia', 'Poland', 'Belgium',
#        'Oman', 'Bangladesh', 'Kazakhstan', 'Brazil', 'Turkey', 'Kenya',
#        'Taiwan', 'Brunei', 'Chile', 'Bulgaria', 'Ukraine', 'Denmark',
#        'Colombia', 'Iran', 'Bahrain', 'Solomon Islands', 'Slovenia',
#        'Mauritius', 'Nepal', 'Russia', 'Kuwait', 'Mexico', 'Sweden',
#        'Austria', 'Lebanon', 'Jordan', 'Greece', 'Mongolia', 'Tanzania',
# ...

# %%
african_countries = ['Algeria', 'Kenya', 'Egypt', 'Ghana', 'Mauritius', 'South Africa', 'Tunisia', 'Tanzania','Seychelles']

# %%
asian_countries = ['Turkey', 'Nepal', 'Japan','Bahrain','Bangladesh', 'Afghanistan','Cambodia','China','India', 'Indonesia', 'Iran', 'Iraq', 'Bhutan', 'Thailand', 'Israel',
                  'Jordan', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia','Oman', 'Kazakhstan', 'Pakistan', 'Qatar','Saudi Arabia', 'Singapore', 'Sri Lanka', 'Philippines', 'Kuwait'
                  'Vietnam','United Arab Emirates','South Korea','Timor-Leste', 'Taiwan','Brunei',
                   ]

# %%
 europe_countries= ['Portugal','Austria', 'Belarus','Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic',
                   'Denmark', 'Poland', 'Romania', 'Estonia', 'France', 'Greece',
                    'Hungary', 'Ireland', 'Italy', 'Malta', 'Netherlands', 'Norway',
                   'Finland', 'Germany', 'Sweden', 'Switzerland', 'Ukraine','United Kingdom', 'Slovenia', 'Spain', 'Gibraltar',
                    'Guam', 'New Caledonia',
                    'Russia']

# %%
oceania = ['Australia', 'New Zealand','Papua New Guinea', 'Solomon Islands', 'Tonga','Vanuatu']

# %%
na_countries = ['Nicaragua','Canada', 'Mexico', 'Guatemala','Panama', 'United States']

# %%
sa_countries = [ 'Argentina', 'Chile', 'Colombia', 'Brazil','Paraguay', 'Peru']

# %%
df.loc[df['booking_origin'].isin(african_countries), 'continent'] = 'Africa'
df.loc[df['booking_origin'].isin(asian_countries), 'continent'] = 'Asia'
df.loc[df['booking_origin'].isin(europe_countries), 'continent'] = 'Europe'
df.loc[df['booking_origin'].isin(na_countries), 'continent'] = 'North America'
df.loc[df['booking_origin'].isin(sa_countries), 'continent'] = 'South America'
df.loc[df['booking_origin'].isin(oceania), 'continent'] = 'Australia and Oceania'
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#   flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0       06:00        Tue  AKLHGH      Australia                    0
# 1       07:00        Sat  AKLDEL    New Zealand                    1
# 2       03:00        Sat  AKLDEL    New Zealand                    0
# 3       17:00        Wed  AKLDEL          India                    1
# 4       04:00        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %% [markdown]
# ### Checking, counting uniques

# %%
top_destinations = df['route'].value_counts().head(10)
top_destinations
# Out:
# route
# AKLKUL    2680
# PENTPE     924
# MELSGN     842
# ICNSIN     801
# DMKKIX     744
# ICNSYD     695
# DMKPER     679
# DPSICN     666
# DMKOOL     655
# MELPEN     649
# Name: count, dtype: int64

# %%
booking_complete_counts = df['booking_complete'].value_counts()
booking_complete_counts
# Out:
# booking_complete
# NO     42523
# YES     7479
# Name: count, dtype: int64

# %%
wants_extra_baggage_counts = df['wants_extra_baggage'].value_counts()
wants_extra_baggage_counts
# Out:
# wants_extra_baggage
# 1    33440
# 0    16562
# Name: count, dtype: int64

# %%
wants_preferred_seat_counts = df['wants_preferred_seat'].value_counts()
wants_preferred_seat_counts
# Out:
# wants_preferred_seat
# 0    35153
# 1    14849
# Name: count, dtype: int64

# %%
wants_in_flight_meals_counts = df['wants_in_flight_meals'].value_counts()
wants_in_flight_meals_counts
# Out:
# wants_in_flight_meals
# 0    28644
# 1    21358
# Name: count, dtype: int64

# %%
df['trip_type'].unique()
# Out:
# array(['RoundTrip', 'CircleTrip', 'OneWay'], dtype=object)

# %%
min_purchase_lead = df['purchase_lead'].min()
max_purchase_lead = df['purchase_lead'].max()

print(f"Minimum value of 'purchase_lead': {min_purchase_lead}")
print(f"Maximum value of 'purchase_lead': {max_purchase_lead}")
# Out:
# Minimum value of 'purchase_lead': 0
# Maximum value of 'purchase_lead': 867

# %%
booked = df[df['booking_complete'] == 1]
booked
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   1      Internet  RoundTrip             21              12
# 84                  1      Internet  RoundTrip             15              31
# 88                  1      Internet  RoundTrip            156              19
# 96                  1      Internet  RoundTrip            181              87
# 111                 1        Mobile  RoundTrip            127              17
# ...               ...           ...        ...            ...             ...
# 49974               1      Internet  RoundTrip             33               6
# 49979               2      Internet  RoundTrip             15               6
# 49982               4      Internet  RoundTrip            242               6
# 49986               2      Internet  RoundTrip              7               6
# 49989               3      Internet  RoundTrip            243               6
#
# ...

# %%
df.describe().T
# Out:
#                          count       mean        std   min    25%    50%  \
# num_passengers         50002.0   1.591256   1.020167  1.00   1.00   1.00
# purchase_lead          50002.0  84.940582  90.450548  0.00  21.00  51.00
# length_of_stay         50002.0  23.044778  33.887171  0.00   5.00  17.00
# flight_hour            50002.0   9.066277   5.412569  0.00   5.00   9.00
# wants_extra_baggage    50002.0   0.668773   0.470659  0.00   0.00   1.00
# wants_preferred_seat   50002.0   0.296968   0.456927  0.00   0.00   0.00
# wants_in_flight_meals  50002.0   0.427143   0.494668  0.00   0.00   0.00
# flight_duration        50002.0   7.277524   1.496854  4.67   5.62   7.57
# booking_complete       50002.0   0.149574   0.356657  0.00   0.00   0.00
#
#                           75%    max
# num_passengers           2.00    9.0
# purchase_lead          115.00  867.0
# length_of_stay          28.00  778.0
# flight_hour             13.00   23.0
# wants_extra_baggage      1.00    1.0
# ...

# %%
booked.describe().T
# Out:
#                         count       mean        std   min    25%    50%  \
# num_passengers         7479.0   1.649819   1.065762  1.00   1.00   1.00
# purchase_lead          7479.0  80.159246  89.833000  0.00  18.00  46.00
# length_of_stay         7479.0  19.616660  33.907414  1.00   5.00   6.00
# flight_hour            7479.0   9.157909   5.236638  0.00   5.00   9.00
# wants_extra_baggage    7479.0   0.745153   0.435804  0.00   0.00   1.00
# wants_preferred_seat   7479.0   0.351518   0.477476  0.00   0.00   0.00
# wants_in_flight_meals  7479.0   0.458350   0.498296  0.00   0.00   0.00
# flight_duration        7479.0   6.898299   1.528085  4.67   5.52   6.62
# booking_complete       7479.0   1.000000   0.000000  1.00   1.00   1.00
#
#                           75%    max
# num_passengers           2.00    9.0
# purchase_lead          106.00  867.0
# length_of_stay          23.00  778.0
# flight_hour             13.00   23.0
# wants_extra_baggage      1.00    1.0
# ...

# %%
columns_to_convert = ['booking_complete']
mapping = {0: 'NO', 1: 'YES'}
df[columns_to_convert] = df[columns_to_convert].replace(mapping)

# %% [markdown]
# ### Calculating % sales channel

# %%
booking_0_internet = df[(df['booking_complete'] == 0) & (df['sales_channel'] == 'Internet')].shape[0]
booking_0_mobile = df[(df['booking_complete'] == 0) & (df['sales_channel'] == 'Mobile')].shape[0]

# %%
booking_1_internet = df[(df['booking_complete'] == 1) & (df['sales_channel'] == 'Internet')].shape[0]
booking_1_mobile = df[(df['booking_complete'] == 1) & (df['sales_channel'] == 'Mobile')].shape[0]

# %%
total_bookings_internet = booking_0_internet + booking_1_internet
total_bookings_mobile = booking_0_mobile + booking_1_mobile

# %%
percentage_booking_0_internet = (booking_0_internet / total_bookings_internet) * 100
percentage_booking_1_internet = (booking_1_internet / total_bookings_internet) * 100

percentage_booking_0_mobile = (booking_0_mobile / total_bookings_mobile) * 100
percentage_booking_1_mobile = (booking_1_mobile / total_bookings_mobile) * 100

# %%
print(f"Percentage of Booking Complete = 0 for Internet: {percentage_booking_0_internet:.2f}%")
print(f"Percentage of Booking Complete = 1 for Internet: {percentage_booking_1_internet:.2f}%")
print(f"Percentage of Booking Complete = 0 for Mobile: {percentage_booking_0_mobile:.2f}%")
print(f"Percentage of Booking Complete = 1 for Mobile: {percentage_booking_1_mobile:.2f}%")
# Out:
# Percentage of Booking Complete = 0 for Internet: 84.52%
# Percentage of Booking Complete = 1 for Internet: 15.48%
# Percentage of Booking Complete = 0 for Mobile: 89.16%
# Percentage of Booking Complete = 1 for Mobile: 10.84%

# %% [markdown]
# ### Bins for purchase lead

# %%
conditions = [
    df['purchase_lead'] < 10,
    df['purchase_lead'] < 30,
    df['purchase_lead'] < 90,
    df['purchase_lead'] < 180,
    df['purchase_lead'] < 361,
    df['purchase_lead'] < 722,
]
bins = [
    'less than 10 days before flight',
    'less than 1 month before flight',
    'less than 3 months before flight',
    '3 - 6 months before flight',
    '6 - 12 months before flight',
    '2 years before the flight',
]

# %%
df['purchase_lead_bin'] = np.select(conditions, bins, default='more than 2 years before the flight')
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            6        Tue  AKLHGH      Australia                    0
# 1            7        Sat  AKLDEL    New Zealand                    1
# 2            3        Sat  AKLDEL    New Zealand                    0
# 3           17        Wed  AKLDEL          India                    1
# 4            4        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
import numpy as np

# %% [markdown]
# ### Flight duration for EU and NA

# %%
euna = df[df['continent'].isin(['Europe', 'North America'])]
euna
# Out:
#        num_passengers sales_channel   trip_type  purchase_lead  \
# 11                  2      Internet   RoundTrip            185
# 69                  3        Mobile  CircleTrip            154
# 98                  2      Internet   RoundTrip            138
# 106                 1      Internet   RoundTrip             93
# 131                 1      Internet   RoundTrip            285
# ...               ...           ...         ...            ...
# 49781               1      Internet   RoundTrip            196
# 49857               5      Internet   RoundTrip             60
# 49928               1      Internet   RoundTrip             23
# 49951               2      Internet   RoundTrip             74
# 49968               2      Internet   RoundTrip             23
#
#        length_of_stay  flight_hour flight_day   route  booking_origin  \
# 11                 25           14        Tue  AKLDEL  United Kingdom
# ...

# %%
euna['flight_duration'].unique()
# Out:
# array([5.52, 8.83, 5.33, 6.62, 4.75, 7.57, 6.42, 5.62, 8.58, 4.72, 5.07,
#        8.15, 7.  , 4.83, 4.67, 5.13, 8.67, 7.42, 6.33, 5.  ])

# %%
bins = [0, 5, 7, float('inf')]
labels = ['long flight', 'very long flight', 'extremely long flight']

# %%
euna['flight_duration_category'] = pd.cut(df['flight_duration'], bins=bins, labels=labels)
# Out:
# C:\Users\alina\AppData\Local\Temp\ipykernel_2920\1131354050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   euna['flight_duration_category'] = pd.cut(df['flight_duration'], bins=bins, labels=labels)

# %%
bins = [0, 5, 7, float('inf')]
labels = ['long flight', 'very long flight', 'extremely long flight']

# Create a new column with the flight duration bins
df['flight_duration_category'] = pd.cut(df['flight_duration'], bins=bins, labels=labels)

# %%
euna.head()
# Out:
#      num_passengers sales_channel   trip_type  purchase_lead  length_of_stay  \
# 11                2      Internet   RoundTrip            185              25
# 69                3        Mobile  CircleTrip            154              45
# 98                2      Internet   RoundTrip            138              35
# 106               1      Internet   RoundTrip             93             196
# 131               1      Internet   RoundTrip            285              30
#
#      flight_hour flight_day   route  booking_origin  wants_extra_baggage  \
# 11            14        Tue  AKLDEL  United Kingdom                    1
# 69             9        Wed  AKLICN          Canada                    1
# 98            19        Fri  AKLKUL     Switzerland                    1
# 106            8        Tue  AKLKUL         Germany                    1
# 131           12        Wed  AKLKUL  Czech Republic                    1
#
# ...

# %% [markdown]
# ### Formating time

# %%
df['flight_hour'].unique()
# Out:
# array([ 6,  7,  3, 17,  4, 15, 20, 14, 12,  2, 19, 10,  8, 23,  9, 13, 11,
#         0,  1,  5, 16, 18, 22, 21], dtype=int64)

# %%
df['flight_hour'] = df['flight_hour'].apply(lambda x: pd.to_datetime(str(x), format='%H').strftime('%H:%M'))
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#   flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0       06:00        Tue  AKLHGH      Australia                    0
# 1       07:00        Sat  AKLDEL    New Zealand                    1
# 2       03:00        Sat  AKLDEL    New Zealand                    0
# 3       17:00        Wed  AKLDEL          India                    1
# 4       04:00        Sat  AKLDEL    New Zealand                    0
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %% [markdown]
# ### Calcutating % for trip type, nr.of passangers for booked

# %%
booked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7392 entries, 0 to 49989
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         7392 non-null   int64
#  1   sales_channel          7392 non-null   int32
#  2   trip_type              7392 non-null   int32
#  3   purchase_lead          7392 non-null   int64
#  4   length_of_stay         7392 non-null   int64
#  5   flight_hour            7392 non-null   int64
#  6   flight_day             7392 non-null   int64
#  7   route                  7392 non-null   object
#  8   booking_origin         7392 non-null   object
#  9   wants_extra_baggage    7392 non-null   int64
#  10  wants_preferred_seat   7392 non-null   int64
#  11  wants_in_flight_meals  7392 non-null   int64
#  12  flight_duration        7392 non-null   float64
#  13  booking_complete       7392 non-null   int64
#  14  continent              7191 non-null   object
# ...

# %%
booked = booked.drop_duplicates()

# %%
booked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7392 entries, 0 to 49989
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         7392 non-null   int64
#  1   sales_channel          7392 non-null   int32
#  2   trip_type              7392 non-null   int32
#  3   purchase_lead          7392 non-null   int64
#  4   length_of_stay         7392 non-null   int64
#  5   flight_hour            7392 non-null   int64
#  6   flight_day             7392 non-null   int64
#  7   route                  7392 non-null   object
#  8   booking_origin         7392 non-null   object
#  9   wants_extra_baggage    7392 non-null   int64
#  10  wants_preferred_seat   7392 non-null   int64
#  11  wants_in_flight_meals  7392 non-null   int64
#  12  flight_duration        7392 non-null   float64
#  13  booking_complete       7392 non-null   int64
#  14  continent              7191 non-null   object
# ...

# %%
num_passengers_counts = booked['num_passengers'].value_counts()
trip_type_counts = booked['trip_type'].value_counts()

# %%
trip_type_counts
# Out:
# trip_type
# 2    7367
# 1      20
# 0       5
# Name: count, dtype: int64

# %%
total_rows = booked.shape[0]
trip_type_counts = booked['trip_type'].value_counts()
trip_type_percentages = (trip_type_counts / total_rows) * 100

# %%
trip_type_percentages
# Out:
# trip_type
# 2    99.661797
# 1     0.270563
# 0     0.067641
# Name: count, dtype: float64

# %%
print("Counts for 'num_passengers':")
print(num_passengers_counts)
# Out:
# Counts for 'num_passengers':
# num_passengers
# 1    4404
# 2    2029
# 3     486
# 4     273
# 5     106
# 6      53
# 7      16
# 9      13
# 8      12
# Name: count, dtype: int64

# %%
total_passengers = booked['num_passengers'].count()
total_passengers
# Out:
# 7392

# %%
categories = {1: '1', 2: '2', 3: '3', 4: '4-8', 5: '4-8', 6: '4-8', 7: '4-8', 8: '4-8', 9: '4-8'}

# %%
booked['passenger_category'] = booked['num_passengers'].map(categories)

# %%
category_counts = booked['passenger_category'].value_counts()
category_percentages = (category_counts / total_passengers) * 100

# %%
category_percentages
# Out:
# passenger_category
# 1      59.577922
# 2      27.448593
# 3       6.574675
# 4-8     6.398810
# Name: count, dtype: float64

# %%
category_counts
# Out:
# passenger_category
# 1      4404
# 2      2029
# 3       486
# 4-8     473
# Name: count, dtype: int64

# %% [markdown]
# ### Extras yes/no

# %%
columns_to_convert = ['wants_extra_baggage', 'wants_preferred_seat', 'wants_in_flight_meals', 'booking_complete']
mapping = {0: 'NO', 1: 'YES'}
df[columns_to_convert] = df[columns_to_convert].replace(mapping)

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
# 1               2      Internet  RoundTrip            262              19
# 2               1      Internet  RoundTrip            112              20
# 3               2      Internet  RoundTrip            243              22
# 4               1      Internet  RoundTrip             96              31
#
#   flight_hour flight_day   route booking_origin wants_extra_baggage  \
# 0       06:00        Tue  AKLHGH      Australia                  NO
# 1       07:00        Sat  AKLDEL    New Zealand                 YES
# 2       03:00        Sat  AKLDEL    New Zealand                  NO
# 3       17:00        Wed  AKLDEL          India                 YES
# 4       04:00        Sat  AKLDEL    New Zealand                  NO
#
#   wants_preferred_seat wants_in_flight_meals  flight_duration  \
# ...

# %% [markdown]
# ### Saving edited df

# %%
df.head(1)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               1      Internet  RoundTrip             21              12
#
#   flight_hour flight_day   route booking_origin wants_extra_baggage  \
# 0       06:00        Tue  AKLHGH      Australia                  NO
#
#   wants_preferred_seat wants_in_flight_meals  flight_duration  \
# 0                   NO                    NO             7.21
#
#   booking_complete              continent                purchase_lead_bin  \
# 0              YES  Australia and Oceania  less than 1 month before flight
#
#   flight_duration_category
# 0    extremely long flight

# %%
#df.to_csv('02_passanger_booking_data_edited.csv')

# %% [markdown]
# ### Visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
plt.figure(figsize=(2, 5))
sns.countplot(data=df, x='booking_complete')
plt.title('Booking Completion')
plt.xlabel('Booking Complete')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='booking_complete', hue='continent')
plt.title('Booking Completion by Region')
plt.xlabel('Booking Complete')
plt.ylabel('Count')
plt.legend(title='Region', loc='upper right')
plt.show()

# %%
selected_columns = [
    'num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
    'length_of_stay', 'flight_hour', 'flight_day', 'wants_extra_baggage',
    'wants_preferred_seat', 'wants_in_flight_meals', 'flight_duration'
]

# %%
label_encoder = LabelEncoder()
for col in ['sales_channel', 'trip_type', 'purchase_lead']:
    booked[col] = label_encoder.fit_transform(booked[col])
# Out:
# C:\Users\alina\AppData\Local\Temp\ipykernel_2920\137364799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   booked[col] = label_encoder.fit_transform(booked[col])
# C:\Users\alina\AppData\Local\Temp\ipykernel_2920\137364799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   booked[col] = label_encoder.fit_transform(booked[col])
# C:\Users\alina\AppData\Local\Temp\ipykernel_2920\137364799.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
days_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
booked['flight_day'] = booked['flight_day'].map(lambda x: days_of_week.index(x))
# Out:
# C:\Users\alina\AppData\Local\Temp\ipykernel_2920\1327391538.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   booked['flight_day'] = booked['flight_day'].map(lambda x: days_of_week.index(x))

# %%
correlation_matrix = booked[selected_columns].corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
selected_columns = [
        'wants_extra_baggage',
    'wants_preferred_seat', 'wants_in_flight_meals', 
]

# %%
correlation_matrix = booked[selected_columns].corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=booked, x='wants_extra_baggage', y='flight_duration')
plt.xlabel('Wants Extra Baggage')
plt.ylabel('Flight Duration')
plt.title('Flight Duration vs. Wants Extra Baggage')
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=booked, x='wants_preferred_seat', y='flight_duration')
plt.xlabel('Wants Preferred Seat')
plt.ylabel('Flight Duration')
plt.title('Flight Duration vs. Wants Preferred Seat')
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=booked, x='wants_in_flight_meals', y='flight_duration')
plt.xlabel('Wants In-Flight Meals')
plt.ylabel('Flight Duration')
plt.title('Flight Duration vs. Wants In-Flight Meals')
plt.show()

# %%
sns.boxplot(data=df, x='booking_complete', y='purchase_lead')

plt.xlabel('Booking Complete (Yes/No)')
plt.ylabel('Purchase Lead (days)')
plt.title('Correlation between Booking Complete and Purchase Lead')

plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='purchase_lead_bin', hue='booking_complete')

plt.xlabel('Purchase Lead Bin')
plt.ylabel('Count')
plt.title('Purchase Lead Bin vs. Booking Complete')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.countplot(data=euna, x='flight_duration_category', hue='wants_extra_baggage')
plt.title('Count of Extra Baggage Preference by Flight Duration Category')
plt.xlabel('Flight Duration Category')
plt.ylabel('Count')
plt.legend(title='Wants Extra Baggage')
plt.show()

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='flight_duration_category', hue='wants_extra_baggage')
plt.title('Count of Extra Baggage Preference by Flight Duration Category')
plt.xlabel('Flight Duration Category')
plt.ylabel('Count')
plt.legend(title='Wants Extra Baggage')
plt.show()

# %%
plt.figure(figsize=(10, 6))

df.groupby('flight_duration_category')[['wants_extra_baggage', 'wants_preferred_seat', 'wants_in_flight_meals']].sum().plot(kind='bar', stacked=True)

plt.title('Preferences by Flight Duration Category')
plt.xlabel('Flight Duration Category')
plt.ylabel('Count')
plt.legend(title='Preference')

plt.show()

# %%
ax = df.groupby('flight_duration_category')[['wants_extra_baggage', 'wants_preferred_seat', 'wants_in_flight_meals']].sum().plot(kind='bar', figsize=(10, 6))

plt.title('Preferences by Flight Duration Category')
plt.xlabel('Flight Duration Category')
plt.ylabel('Count')
plt.legend(title='Preference', labels=['Extra Baggage', 'Preferred Seat', 'In-flight Meals'])

plt.show()
